# %%
import numpy as np
import pandas as pd
import math

# %%
df = pd.read_csv("resources/divar_posts_dataset.csv")

# %%
dfcat1 = df.loc[df.cat2!=df.cat2]
dfcat1["cat"] = dfcat1["cat1"]
# Out:
# /Users/amirkasra/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dfcat2 = df.loc[(df.cat3!=df.cat3) & (df.cat2==df.cat2)]
dfcat2["cat"] = (dfcat2["cat1"]+ ":" +dfcat2["cat2"])
# Out:
# /Users/amirkasra/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dfcat3 = df.loc[(df.cat3==df.cat3)]
dfcat3["cat"] = (dfcat3["cat1"]+ ":" +dfcat3["cat2"] + ":" + dfcat3["cat3"])
# Out:
# /Users/amirkasra/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data = dfcat1.append(dfcat2.append(dfcat3))

# %%
data
# Out:
#         Unnamed: 0  archive_by_user                   brand  \
# 34              34            False                     NaN
# 99              99            False                     NaN
# 164            164             True                     NaN
# 619            619            False                     NaN
# 710            710            False                     NaN
# 1391          1391            False                     NaN
# 1432          1432            False                     NaN
# 2213          2213             True                     NaN
# 3610          3610             True                     NaN
# 3858          3858            False                     NaN
# 4557          4557             True                     NaN
# 5081          5081            False                     NaN
# 5152          5152            False                     NaN
# 5493          5493            False                     NaN
# 6210          6210            False                     NaN
# 6239          6239             True                     NaN
# 6443          6443            False                     NaN
# 6840          6840            False                     NaN
# 7203          7203            False                     NaN
# 8229          8229            False                     NaN
# 9825          9825            False                     NaN
# 9833          9833            False                     NaN
# 9841          9841            False                     NaN
# 9960          9960            False                     NaN
# 10050        10050            False                     NaN
# 11485        11485            False                     NaN
# 11852        11852            False                     NaN
# 12512        12512            False                     NaN
# 12548        12548             True                     NaN
# 12823        12823             True                     NaN
# ...            ...              ...                     ...
# 947602      947602             True  پراید صندوق‌دار::Pride
# 947604      947604             True                     NaN
# 947605      947605             True                     NaN
# 947606      947606             True                     NaN
# 947607      947607             True                     NaN
# 947608      947608             True                     NaN
# 947609      947609             True    پژو ۴۰۵::Peugeot 405
# 947610      947610             True              Apple::اپل
# 947611      947611             True                     NaN
# 947612      947612             True                     NaN
# 947613      947613             True                     NaN
# 947614      947614             True                     NaN
# 947615      947615             True            سمند::Samand
# 947616      947616             True                     NaN
# 947617      947617             True                     NaN
# 947619      947619             True                     NaN
# 947620      947620             True                     NaN
# 947621      947621             True        Samsung::سامسونگ
# 947622      947622             True              Sony::سونی
# 947623      947623             True                     NaN
# 947624      947624             True                     NaN
# 947625      947625             True  پراید صندوق‌دار::Pride
# 947626      947626             True                     NaN
# 947627      947627             True                     NaN
# 947628      947628             True                     NaN
# 947630      947630             True                     NaN
# 947631      947631             True                     NaN
# 947632      947632             True  پراید صندوق‌دار::Pride
# 947633      947633             True                     NaN
# 947634      947634             True                     NaN
#
#                       cat1                       cat2  \
# 34      electronic-devices                        NaN
# 99                personal                        NaN
# 164               personal                        NaN
# 619               personal                        NaN
# 710     electronic-devices                        NaN
# 1391    electronic-devices                        NaN
# 1432    electronic-devices                        NaN
# 2213    electronic-devices                        NaN
# 3610    electronic-devices                        NaN
# 3858              personal                        NaN
# 4557    electronic-devices                        NaN
# 5081    electronic-devices                        NaN
# 5152    electronic-devices                        NaN
# 5493    electronic-devices                        NaN
# 6210    electronic-devices                        NaN
# 6239              personal                        NaN
# 6443    electronic-devices                        NaN
# 6840    electronic-devices                        NaN
# 7203    electronic-devices                        NaN
# 8229    electronic-devices                        NaN
# 9825    electronic-devices                        NaN
# 9833    electronic-devices                        NaN
# 9841    electronic-devices                        NaN
# 9960    electronic-devices                        NaN
# 10050   electronic-devices                        NaN
# 11485   electronic-devices                        NaN
# 11852   electronic-devices                        NaN
# 12512             personal                        NaN
# 12548   electronic-devices                        NaN
# 12823             personal                        NaN
# ...                    ...                        ...
# 947602            vehicles                       cars
# 947604        for-the-home  furniture-and-home-decore
# 947605  electronic-devices                audio-video
# 947606        for-the-home        building-and-garden
# 947607        for-the-home  furniture-and-home-decore
# 947608        for-the-home    utensils-and-appliances
# 947609            vehicles                       cars
# 947610  electronic-devices              mobile-tablet
# 947611          businesses   equipments-and-machinery
# 947612            vehicles                       cars
# 947613        for-the-home  furniture-and-home-decore
# 947614            vehicles                       cars
# 947615            vehicles                       cars
# 947616            personal         clothing-and-shoes
# 947617        for-the-home  furniture-and-home-decore
# 947619        for-the-home  furniture-and-home-decore
# 947620        for-the-home  furniture-and-home-decore
# 947621  electronic-devices              mobile-tablet
# 947622  electronic-devices              mobile-tablet
# 947623          businesses   equipments-and-machinery
# 947624            personal              baby-and-toys
# 947625            vehicles                       cars
# 947626  electronic-devices                audio-video
# 947627        for-the-home    utensils-and-appliances
# 947628        for-the-home  furniture-and-home-decore
# 947630        for-the-home        building-and-garden
# 947631  electronic-devices                audio-video
# 947632            vehicles                       cars
# 947633  electronic-devices              mobile-tablet
# 947634            personal        jewelry-and-watches
#
#                              cat3        city      created_at  \
# 34                            NaN      Tehran   Thursday 02AM
# 99                            NaN      Tehran     Sunday 07AM
# 164                           NaN      Tehran  Wednesday 01PM
# 619                           NaN      Tehran   Thursday 05PM
# 710                           NaN      Tehran     Sunday 10AM
# 1391                          NaN      Tehran     Monday 03PM
# 1432                          NaN      Tehran    Tuesday 09PM
# 2213                          NaN      Tehran  Wednesday 07PM
# 3610                          NaN     Mashhad     Sunday 11PM
# 3858                          NaN      Tehran     Friday 09AM
# 4557                          NaN     Mashhad  Wednesday 04PM
# 5081                          NaN     Mashhad     Friday 01AM
# 5152                          NaN     Mashhad     Sunday 11AM
# 5493                          NaN      Tehran   Thursday 10AM
# 6210                          NaN      Tehran   Saturday 08PM
# 6239                          NaN      Tehran     Sunday 05PM
# 6443                          NaN      Tehran   Saturday 03PM
# 6840                          NaN      Tehran   Saturday 03PM
# 7203                          NaN      Tehran   Saturday 02PM
# 8229                          NaN      Tehran   Thursday 02PM
# 9825                          NaN      Tehran   Thursday 04PM
# 9833                          NaN      Tehran   Thursday 06PM
# 9841                          NaN      Tehran     Friday 05AM
# 9960                          NaN      Tehran    Tuesday 05PM
# 10050                         NaN      Tehran     Friday 05PM
# 11485                         NaN      Tehran     Friday 01PM
# 11852                         NaN      Tehran     Friday 08AM
# 12512                         NaN      Tehran     Monday 04PM
# 12548                         NaN     Mashhad    Tuesday 08AM
# 12823                         NaN      Tehran     Sunday 11AM
# ...                           ...         ...             ...
# 947602                      light     Isfahan    Tuesday 05PM
# 947604              sofa-armchair     Isfahan    Tuesday 05PM
# 947605               tv-projector  Kermanshah    Tuesday 07PM
# 947606          stove-and-heating     Mashhad    Tuesday 09PM
# 947607          tables-and-chairs      Tehran  Wednesday 05AM
# 947608         cookware-tableware      Tehran  Wednesday 07AM
# 947609                      light      Shiraz  Wednesday 08AM
# 947610              mobile-phones      Tehran  Wednesday 11AM
# 947611              shop-and-cash  Kermanshah  Wednesday 11AM
# 947612                      heavy      Tehran  Wednesday 03PM
# 947613          tables-and-chairs       Karaj  Wednesday 05PM
# 947614                      heavy     Isfahan  Wednesday 06PM
# 947615                      light      Shiraz  Wednesday 06PM
# 947616                   clothing       Ahvaz   Thursday 04AM
# 947617           antiques-and-art  Kermanshah   Thursday 04AM
# 947619              sofa-armchair      Tehran   Thursday 07AM
# 947620              sofa-armchair      Tehran   Thursday 08AM
# 947621              mobile-phones      Tehran   Thursday 09AM
# 947622              mobile-phones     Mashhad   Thursday 11AM
# 947623                 industrial      Tehran   Thursday 11AM
# 947624             child-car-seat      Tehran   Thursday 12PM
# 947625                      light       Karaj   Thursday 03PM
# 947626            stereo-surround       Karaj   Thursday 05PM
# 947627         cookware-tableware      Tehran   Thursday 05PM
# 947628              sofa-armchair      Tehran   Thursday 05PM
# 947630          stove-and-heating      Shiraz     Friday 07AM
# 947631           camera-camcoders      Tehran     Friday 02PM
# 947632                      light      Shiraz     Friday 04PM
# 947633  mobile-tablet-accessories     Mashhad     Friday 05PM
# 947634                    watches      Shiraz     Friday 05PM
#
#                                                      desc              id  \
# 34                            حدود 33 متر کابل مفتولی 4*6   1137276559195
# 99      جنس چتر از ساتنه سایزش بزرگه\nدسته چتر با بدنه...   3748386024591
# 164                                رنگ آبی اکبند دانشجویی  22187152508462
# 619         گوی اعصاب کاملا تمیز و نو خیلی کم استفاده شده  60619246221783
# 710                           ترموستات 900\nدر جعبه نو نو  19665758010091
# 1391                                   کولر:موتورژن -3500  22419836618997
# 1432      وارد کننده دوربینهای اوکای ویژن زیر قیمت واردات  19115305930834
# 2213                لطفا قبل از تماس گرفتن اس ام اس بدهید   3976462757088
# 3610                                کیفیت 1mp\nدیددرشب20m  57878037736511
# 3858     مارک فابل کستل \nبا جعبه چوبی و فلزی \nاصل المان  12929847977570
# 4557    دو عدد ای سی 100w واقعی و تا 150 هم میرسه به ش...  60113808781871
# 5081                                     کاسیو ،نو میباشد  10393372789619
# 5152    بعد از خریدن پشیمون شدم و کاملا نویه برا همین ...  25972186067577
# 5493    باسلام این یوپی اس  550خودم خریدم اصلااستفاده ...  14824526811749
# 6210    DVRچهار کاناله \nدو دوربین دید در شب یکی سقفی ...  10150494389916
# 6239    فندک های اورجینال zippo با بیش از ۴۰۰ مدل\nحکا...  47213808326153
# 6443             لوستر سفید وزرد  220وات هزار وپنصد تومان  60012789528305
# 6840    سه عدد دوربین مخفی به شکل آینه گرد -سیلندر لام...  23628200341143
# 7203    توسط این رله میتوان بسیاری از وسایل را از راه ...  36608778124251
# 8229    فروش یو پی اس برق اضطراری \nتک فاز و سه فاز \n...  54035060696775
# 9825                                کاملا سالم و در حد نو  61814958412348
# 9833    سلام ۵ توپ کابل بلندگو دارم هر توپش ۱۰۰ متره$N...   9184129444572
# 9841    ماشین حساب مهندسی \nبهترین مدل کاسیو \nهرچیو ک...    187613148903
# 9960                                 آکبند زیر قیمت بازار  38601155211481
# 10050   یک عدد دوربین مادون قرمزدیددرشب.حافظه 500گیک ....  45325197233498
# 11485   ماشین حساب دست دوم کم کار کرده اول نو اشو بپرس...  59656433072680
# 11852   کامپیوتر مهندسی ti-nspire cas متعلق به کمپانی ...   7473964742684
# 12512                         چند بسته کاغذ A4 موجود است.  28828383200715
# 12548   دوعددترانس ۱۱۰ ولت برای ضبطهای طبقاتی.سالم.قیم...  55378933610643
# 12823   سه پایه نقاشی حرفه ای-کاملا سالم\nقابلیت تنظیم...   2086301919390
# ...                                                   ...             ...
# 947602  مدل 84 تمیز. بدون رنگ. سیستم صوتی. رینگ و لاست...  36679901713761
# 947604  با سلام \nمبلمان هفت نفره و همانطور که تو عکس ...  24085275306660
# 947605  سلام تلویزیون درحد نوو تمیز دیجیتال دار تخفیف ...  11663382531270
# 947606                    بخاری آلیش گاز تمیز\nسالم ومرتب   1612990731772
# 947607  تولیدی صنایع چوبی فریدپور تولید کننده انواع مب...  33249797540027
# 947608  همه نو وسالم استفاده نشده چند وقت پیش از نماین...  36285186767743
# 947609  ۴۰۵slxیا همان tufصفر کیلومتر سند خورده تحویل د...  30077906536153
# 947610      جعبه ولوازم LLAاصل/بدون خط وخش/باز نشده/سالم.    132753009802
# 947611  بلندی 2 متر پنها 1 متر عمق 40 ثانت\nچهار طبقه ...  61466620806128
# 947612  بادسان فوق بیرنگ سفید رنگ بیمه تابرج 3.96 تخفی...  21866530196097
# 947613                                   4نفره تمیز سبک .   6518293923049
# 947614  باسلام .تراکتورازصفری دست خودم بوده.سالم.ودارا...  44067752978166
# 947615      ماشینم تصادفیه با خریدار توافق میکنم سر قیمتش  32248935135739
# 947616                سلام.کاملا اکبند هستش،و هیچ نپوشیدم  53252710020814
# 947617  انواع گلهای کریستالی،توری،تل وگیرژله ای سفارش ...  63799201859273
# 947619  مبل ٩ نفره همراه با میز وسط و یک عدد عسلی مبلم...  53006184204970
# 947620  مبلمان هفت نفره شیک و تمیز همراه با میز جلویی ...  64279503963911
# 947621  سالم و تمیز با لوازم\nاندروید 5. باتری اورجینا...  20251684311504
# 947622  فروش یا معاوضه فوری فوری\nسفید تمیز همراه با گ...  48122459746674
# 947623  فروش دو عدد دستگاه بلوک زنی (لیکا)\n15*20*40\n...  15026572391599
# 947624  صندلی کودک مارک چیکو دقیقا مدل و رنگ دز دیوار ...   6072997698913
# 947625  سند۲ برگ،بیمه تا برج$NUMتخفیفات بیمه 15 سال،مع...  30197850752025
# 947626  با سلام خدمت شما \nاین دستگاه تمیزه سالمه ۲۴۰۰...  30247035759677
# 947627  بهتوین زودپزه اگه کسی بشناسه\nبه علت جا به جای...  12624632523188
# 947628                       با دوسال ضمانت تشکر از دیوار  38646519610598
# 947630  دوعدد یکی یک متری و دیگری 1.4 متری موجود است\n...  16127180351093
# 947631  دوربین هندی کم کنون مدل لگریا fs36\n\nعکاسی و ...  29805298491725
# 947632  پراید دوگانه کارخانه میباشد و کم کارکرد.روکش ....  55514317985619
# 947633  مونو پد یانگ تد همراه با پایه و اینه عقبش\nواس...  65938921533442
# 947634                           جواب فقط تماس و. وات ساپ  18312774360687
#
#         image_count   mileage platform     price  \
# 34                3       NaN   mobile        -1
# 99                2       NaN   mobile     15000
# 164               2       NaN   mobile     20000
# 619               2       NaN   mobile     40000
# 710               2       NaN   mobile        -1
# 1391              0       NaN   mobile        -1
# 1432              5       NaN   mobile     60000
# 2213              3       NaN      web        -1
# 3610              0       NaN   mobile     49000
# 3858              2       NaN   mobile    120000
# 4557              4       NaN   mobile     25900
# 5081              0       NaN   mobile     50000
# 5152              1       NaN   mobile     38000
# 5493              3       NaN   mobile    450000
# 6210              1       NaN   mobile    600000
# 6239              4       NaN   mobile        -1
# 6443              2       NaN   mobile     15000
# 6840              1       NaN      web    150000
# 7203              1       NaN   mobile     80000
# 8229              1       NaN   mobile        -1
# 9825              1       NaN   mobile        -1
# 9833              1       NaN   mobile    170000
# 9841              1       NaN   mobile    370000
# 9960              4       NaN   mobile     27000
# 10050             4       NaN   mobile    350000
# 11485             1       NaN   mobile    637000
# 11852             1       NaN      web    700000
# 12512             2       NaN   mobile      9000
# 12548             0       NaN   mobile    100000
# 12823             2       NaN      web    100000
# ...             ...       ...      ...       ...
# 947602            3  140000.0   mobile  11000000
# 947604            3       NaN   mobile        -1
# 947605            1       NaN   mobile    650000
# 947606            3       NaN   mobile     90000
# 947607            1       NaN   mobile    680000
# 947608            2       NaN   mobile    250000
# 947609            3       1.0   mobile        -1
# 947610            2       NaN   mobile    720000
# 947611            1       NaN   mobile    150000
# 947612            2       NaN   mobile  48000000
# 947613            2       NaN   mobile    150000
# 947614            4       NaN   mobile        -1
# 947615            3   20000.0      web        -1
# 947616            1       NaN   mobile        -1
# 947617            2       NaN   mobile     35000
# 947619            1       NaN   mobile    400000
# 947620            3       NaN   mobile        -1
# 947621            2       NaN   mobile    475000
# 947622            0       NaN      web    650000
# 947623            1       NaN      web        -1
# 947624            1       NaN   mobile    180000
# 947625            4  123000.0   mobile   6900000
# 947626            2       NaN   mobile        -1
# 947627            3       NaN   mobile    350000
# 947628            5       NaN   mobile   2200000
# 947630            1       NaN      web    180000
# 947631            1       NaN   mobile    350000
# 947632            3   43000.0   mobile  17400000
# 947633            1       NaN   mobile     40000
# 947634            1       NaN   mobile     25000
#
#                                        title type  year  \
# 34              کابل 4*6 خشک سالم کار نکرده.  NaN   NaN
# 99                             چتر ساتن بنفش  NaN   NaN
# 164                        خودکار یوروپن اصل  NaN   NaN
# 619                                گوی اعصاب  NaN   NaN
# 710                             ترموستات 900  NaN   NaN
# 1391               دینام کولروماشین لباسشویی  NaN   NaN
# 1432                   دوربین فروش کلی وجزعی  NaN   NaN
# 2213                  یو پی اس سینوسی online  NaN   NaN
# 3610                     دوربین دید درشب AHD  NaN   NaN
# 3858       مداد رنگی حرفه ای ٢٥ رنگ پلی کروم  NaN   NaN
# 4557                   ای سی 100w امپلی فایر  NaN   NaN
# 5081               ماشین حساب مهندسی،حرفه ای  NaN   NaN
# 5152               ریموت کنترل چهار کانال نو  NaN   NaN
# 5493                                 یوپی اس  NaN   NaN
# 6210                     ست دوربین مدار بسته  NaN   NaN
# 6239                  فندک های اورجینال زیپو  NaN   NaN
# 6443                      پخش لامپ ها ژله ای  NaN   NaN
# 6840                         دوربین     مخفی  NaN   NaN
# 7203                     رله ۱۲ کانال ریموتی  NaN   NaN
# 8229               فروش یو پی اس برق اضطراری  NaN   NaN
# 9825                        ماشین حساب کاسیو  NaN   NaN
# 9833                             کابل بلندگو  NaN   NaN
# 9841    ماشین حساب   casio classpad plus 330  NaN   NaN
# 9960         ماشین حساب آکبند ،سیتی زن،چک کن  NaN   NaN
# 10050              دوربین مداربسته .سیماران.  NaN   NaN
# 11485         ماشین حساب algebra fx 2.0 plus  NaN   NaN
# 11852           ماشین حساب (کامپیوتر) مهندسی  NaN   NaN
# 12512                                کاغذ A4  NaN   NaN
# 12548                          ترانس ۱۱۰ ولت  NaN   NaN
# 12823                          سه پایه نقاشی  NaN   NaN
# ...                                      ...  ...   ...
# 947602                 پراید مدل 84 بدون رنگ  NaN  1384
# 947604                 مبل راحتی فروش توافقی  NaN   NaN
# 947605                   تلویزیون ال ای دی32  NaN   NaN
# 947606                   بخاری آلیش گاز تمیز  NaN   NaN
# 947607                         غذاخوری 4نفره  NaN   NaN
# 947608                          ظروف لوردشید  NaN   NaN
# 947609                                ۴۰۵slx  NaN  1395
# 947610                         /١٦gig/5s/گلد  NaN   NaN
# 947611                ویترین ایستاده در حدنو  NaN   NaN
# 947612                     بادسان 8b14 مدل83  NaN   NaN
# 947613          میز نهارخوری4نفره بسیار تمیز  NaN   NaN
# 947614              تراکتورگلدونی ۲۳۸ایتالیا  NaN   NaN
# 947615               خودرو سمند تصادفی مدل92  NaN  1392
# 947616               لباس و اورکت ارتش نو نو  men   NaN
# 947617                           گل کریستالی  NaN   NaN
# 947619                      مبل راحتی ٩ نفره  NaN   NaN
# 947620                       مبلمان هفت نفره  NaN   NaN
# 947621                 گلکسی galaxy s4 i9500  NaN   NaN
# 947622                سونی Z2فورجی سفیدD6503  NaN   NaN
# 947623       دستگاه بلوک زنی (لیکا) - دو عدد  NaN   NaN
# 947624                            صندلی کودک  NaN   NaN
# 947625                   پراید 79 بسیار سالم  NaN  1379
# 947626                      ظبط سه دیسک آیوا  NaN   NaN
# 947627                     زودپز کلیپسو تفال  NaN   NaN
# 947628                           تولید کننده  NaN   NaN
# 947630                  رادیاتور پنلی نو ترک  NaN   NaN
# 947631                  دوربین هندی کم  کنون  NaN   NaN
# 947632            پراید دوگانه کارخانه مدل93  NaN  1393
# 947633         مونوپد یانگ تد خیلی تمیز و نو  NaN   NaN
# 947634                             ساعت مارک  NaN   NaN
#
#                                                       cat
# 34                                     electronic-devices
# 99                                               personal
# 164                                              personal
# 619                                              personal
# 710                                    electronic-devices
# 1391                                   electronic-devices
# 1432                                   electronic-devices
# 2213                                   electronic-devices
# 3610                                   electronic-devices
# 3858                                             personal
# 4557                                   electronic-devices
# 5081                                   electronic-devices
# 5152                                   electronic-devices
# 5493                                   electronic-devices
# 6210                                   electronic-devices
# 6239                                             personal
# 6443                                   electronic-devices
# 6840                                   electronic-devices
# 7203                                   electronic-devices
# 8229                                   electronic-devices
# 9825                                   electronic-devices
# 9833                                   electronic-devices
# 9841                                   electronic-devices
# 9960                                   electronic-devices
# 10050                                  electronic-devices
# 11485                                  electronic-devices
# 11852                                  electronic-devices
# 12512                                            personal
# 12548                                  electronic-devices
# 12823                                            personal
# ...                                                   ...
# 947602                                vehicles:cars:light
# 947604  for-the-home:furniture-and-home-decore:sofa-ar...
# 947605        electronic-devices:audio-video:tv-projector
# 947606  for-the-home:building-and-garden:stove-and-hea...
# 947607  for-the-home:furniture-and-home-decore:tables-...
# 947608  for-the-home:utensils-and-appliances:cookware-...
# 947609                                vehicles:cars:light
# 947610     electronic-devices:mobile-tablet:mobile-phones
# 947611  businesses:equipments-and-machinery:shop-and-cash
# 947612                                vehicles:cars:heavy
# 947613  for-the-home:furniture-and-home-decore:tables-...
# 947614                                vehicles:cars:heavy
# 947615                                vehicles:cars:light
# 947616               personal:clothing-and-shoes:clothing
# 947617  for-the-home:furniture-and-home-decore:antique...
# 947619  for-the-home:furniture-and-home-decore:sofa-ar...
# 947620  for-the-home:furniture-and-home-decore:sofa-ar...
# 947621     electronic-devices:mobile-tablet:mobile-phones
# 947622     electronic-devices:mobile-tablet:mobile-phones
# 947623     businesses:equipments-and-machinery:industrial
# 947624              personal:baby-and-toys:child-car-seat
# 947625                                vehicles:cars:light
# 947626     electronic-devices:audio-video:stereo-surround
# 947627  for-the-home:utensils-and-appliances:cookware-...
# 947628  for-the-home:furniture-and-home-decore:sofa-ar...
# 947630  for-the-home:building-and-garden:stove-and-hea...
# 947631    electronic-devices:audio-video:camera-camcoders
# 947632                                vehicles:cars:light
# 947633  electronic-devices:mobile-tablet:mobile-tablet...
# 947634               personal:jewelry-and-watches:watches
#
# [947635 rows x 18 columns]

# %%
# Out:
# 34                                       electronic-devices
# 99                                                 personal
# 164                                                personal
# 619                                                personal
# 710                                      electronic-devices
# 1391                                     electronic-devices
# 1432                                     electronic-devices
# 2213                                     electronic-devices
# 3610                                     electronic-devices
# 3858                                               personal
# 4557                                     electronic-devices
# 5081                                     electronic-devices
# 5152                                     electronic-devices
# 5493                                     electronic-devices
# 6210                                     electronic-devices
# 6239                                               personal
# 6443                                     electronic-devices
# 6840                                     electronic-devices
# 7203                                     electronic-devices
# 8229                                     electronic-devices
# 9825                                     electronic-devices
# 9833                                     electronic-devices
# 9841                                     electronic-devices
# 9960                                     electronic-devices
# 10050                                    electronic-devices
# 11485                                    electronic-devices
# 11852                                    electronic-devices
# 12512                                              personal
# 12548                                    electronic-devices
# 12823                                              personal
#                                 ...
# 947602                                  vehicles:cars:light
# 947604    for-the-home:furniture-and-home-decore:sofa-ar...
# 947605          electronic-devices:audio-video:tv-projector
# 947606    for-the-home:building-and-garden:stove-and-hea...
# 947607    for-the-home:furniture-and-home-decore:tables-...
# 947608    for-the-home:utensils-and-appliances:cookware-...
# 947609                                  vehicles:cars:light
# 947610       electronic-devices:mobile-tablet:mobile-phones
# 947611    businesses:equipments-and-machinery:shop-and-cash
# 947612                                  vehicles:cars:heavy
# 947613    for-the-home:furniture-and-home-decore:tables-...
# 947614                                  vehicles:cars:heavy
# 947615                                  vehicles:cars:light
# 947616                 personal:clothing-and-shoes:clothing
# 947617    for-the-home:furniture-and-home-decore:antique...
# 947619    for-the-home:furniture-and-home-decore:sofa-ar...
# 947620    for-the-home:furniture-and-home-decore:sofa-ar...
# 947621       electronic-devices:mobile-tablet:mobile-phones
# 947622       electronic-devices:mobile-tablet:mobile-phones
# 947623       businesses:equipments-and-machinery:industrial
# 947624                personal:baby-and-toys:child-car-seat
# 947625                                  vehicles:cars:light
# 947626       electronic-devices:audio-video:stereo-surround
# 947627    for-the-home:utensils-and-appliances:cookware-...
# 947628    for-the-home:furniture-and-home-decore:sofa-ar...
# 947630    for-the-home:building-and-garden:stove-and-hea...
# 947631      electronic-devices:audio-video:camera-camcoders
# 947632                                  vehicles:cars:light
# 947633    electronic-devices:mobile-tablet:mobile-tablet...
# 947634                 personal:jewelry-and-watches:watches
# Name: cat, Length: 947635, dtype: object
