# %%
import csv
import pandas as pd
import locale
locale.setlocale(locale.LC_ALL, 'Persian')
# %config IPCompleter.greedy=True
df = pd.read_csv("./resources/divar_posts_dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  archive_by_user brand          cat1                       cat2  \
# 0           0            False   NaN  for-the-home  furniture-and-home-decore
# 1           1            False   NaN  for-the-home  furniture-and-home-decore
# 2           2            False   NaN      vehicles                       cars
# 3           3            False   NaN  for-the-home  furniture-and-home-decore
# 4           4            False   NaN      personal              baby-and-toys
#
#                cat3     city    created_at  \
# 0     sofa-armchair   Tehran  Tuesday 07PM
# 1  antiques-and-art  Mashhad  Tuesday 07PM
# 2             heavy  Mashhad  Tuesday 07PM
# 3     sofa-armchair   Tehran  Tuesday 07PM
# 4     personal-toys    Karaj  Tuesday 08PM
#
#                                                 desc              id  \
# 0  کلاسیک و شیک و استثنایی\nچرم مالزی\nچوب راش\nف...  54761638662241
# 1  سلام,یک عدد گلدون نخل سه طبقه ی سالم دارم با پ...  42727631379133
# 2  سریال 43j$NUMبدون شکستگی سه حلقه لاستیک نو یک ...  63194439667302
# 3  مبل راحتی هفت نفره شامل سه نفره یک عدد دونفره ...  19133025491169
# 4  شارژی کنترلی سویچ حمل تا 35 کیلو صندلی برای دو...  58998998335444
#
#    image_count  mileage platform    price                              title  \
# 0            5      NaN   mobile  3850000        ست مبلمان و نهارخوری ٩ نفره
# 1            1      NaN   mobile    30000                   گلدون مصنوعی نخل
# 2            4      NaN   mobile       -1                لودر کاتر پیلار 950
# 3            4      NaN   mobile   600000  مبل راحتی هفت نفره بامیز جلو مبلی
# 4            2      NaN   mobile   450000                        ماشین شارژی
#
#   type year
# 0  NaN  NaN
# 1  NaN  NaN
# 2  NaN  NaN
# 3  NaN  NaN
# 4  NaN  NaN

# %%
dfcat1 = df.loc[df.cat2!=df.cat2]
dfcat1["cat"] = dfcat1["cat1"]
dfcat2 = df.loc[(df.cat3!=df.cat3) & (df.cat2==df.cat2)]
dfcat2["cat"] = (dfcat2["cat1"]+ ":" +dfcat2["cat2"])
dfcat3 = df.loc[(df.cat3==df.cat3)]
dfcat3["cat"] = (dfcat3["cat1"]+ ":" +dfcat3["cat2"] + ":" + dfcat3["cat3"])
data = dfcat1.append(dfcat2.append(dfcat3))
                    
#datas["tree_cat"] = (datas["cat1"]+":"+datas["cat2"]+":"+datas["cat3"])
data.head()
data.info()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 947635 entries, 34 to 947634
# Data columns (total 18 columns):
# Unnamed: 0         947635 non-null int64
# archive_by_user    947635 non-null bool
# brand              190892 non-null object
# cat1               947635 non-null object
# cat2               945877 non-null object
# cat3               775301 non-null object
# city               947635 non-null object
# created_at         947635 non-null object
# desc               947635 non-null object
# id                 947635 non-null int64
# image_count        947635 non-null int64
# mileage            120451 non-null float64
# platform           947635 non-null object
# price              947635 non-null int64
# title              947635 non-null object
# type               98529 non-null object
# year               120451 non-null object
# cat                947635 non-null object
# dtypes: bool(1), float64(1), int64(4), object(12)
# memory usage: 131.0+ MB

# %%
data.cat
# Out:
# 34                                       electronic-devices
# 99                                                 personal
# 164                                                personal
# 619                                                personal
# 710                                      electronic-devices
# 1391                                     electronic-devices
# 1432                                     electronic-devices
# 2213                                     electronic-devices
# 3610                                     electronic-devices
# 3858                                               personal
# 4557                                     electronic-devices
# 5081                                     electronic-devices
# 5152                                     electronic-devices
# 5493                                     electronic-devices
# 6210                                     electronic-devices
# 6239                                               personal
# 6443                                     electronic-devices
# 6840                                     electronic-devices
# 7203                                     electronic-devices
# 8229                                     electronic-devices
# 9825                                     electronic-devices
# 9833                                     electronic-devices
# 9841                                     electronic-devices
# 9960                                     electronic-devices
# 10050                                    electronic-devices
# 11485                                    electronic-devices
# 11852                                    electronic-devices
# 12512                                              personal
# 12548                                    electronic-devices
# 12823                                              personal
#                                 ...
# 947602                                  vehicles:cars:light
# 947604    for-the-home:furniture-and-home-decore:sofa-ar...
# 947605          electronic-devices:audio-video:tv-projector
# 947606    for-the-home:building-and-garden:stove-and-hea...
# 947607    for-the-home:furniture-and-home-decore:tables-...
# 947608    for-the-home:utensils-and-appliances:cookware-...
# 947609                                  vehicles:cars:light
# 947610       electronic-devices:mobile-tablet:mobile-phones
# 947611    businesses:equipments-and-machinery:shop-and-cash
# 947612                                  vehicles:cars:heavy
# 947613    for-the-home:furniture-and-home-decore:tables-...
# 947614                                  vehicles:cars:heavy
# 947615                                  vehicles:cars:light
# 947616                 personal:clothing-and-shoes:clothing
# 947617    for-the-home:furniture-and-home-decore:antique...
# 947619    for-the-home:furniture-and-home-decore:sofa-ar...
# 947620    for-the-home:furniture-and-home-decore:sofa-ar...
# 947621       electronic-devices:mobile-tablet:mobile-phones
# 947622       electronic-devices:mobile-tablet:mobile-phones
# 947623       businesses:equipments-and-machinery:industrial
# 947624                personal:baby-and-toys:child-car-seat
# 947625                                  vehicles:cars:light
# 947626       electronic-devices:audio-video:stereo-surround
# 947627    for-the-home:utensils-and-appliances:cookware-...
# 947628    for-the-home:furniture-and-home-decore:sofa-ar...
# 947630    for-the-home:building-and-garden:stove-and-hea...
# 947631      electronic-devices:audio-video:camera-camcoders
# 947632                                  vehicles:cars:light
# 947633    electronic-devices:mobile-tablet:mobile-tablet...
# 947634                 personal:jewelry-and-watches:watches
# Name: cat, Length: 947635, dtype: object

# %%
 import re
dic={}
def rngrams(input):
    input = input.replace('\n',' ')
    input = input.replace('.',' ')
    input = input.replace(' ',' ')
    input = input.replace(',',' ')
    input = input.replace('،',' ')
    input = re.split(' ',input)
    
    for word in input:
            dic.setdefault(word, 0)
            dic[word] += 1

# %%
for i in range(0,df.shape[0]):
    row = data.iloc[i]
    rngrams(row.desc)
    rngrams(row.title)

# %%
dic
# Out:
# {'حدود': 5213,
#  '33': 370,
#  'متر': 10859,
#  'کابل': 5491,
#  'مفتولی': 16,
#  '4*6': 7,
#  'خشک': 3149,
#  'سالم': 274572,
#  'کار': 43154,
#  'نکرده': 3337,
#  '': 1262928,
#  'جنس': 15758,
#  'چتر': 121,
#  'از': 118342,
#  'ساتنه': 26,
#  'سایزش': 1352,
#  'بزرگه': 995,
#  'دسته': 12986,
#  'با': 263707,
#  'بدنه': 11260,
#  'سته': 50,
#  'کاور': 4561,
#  'روش': 5765,
#  'داره': 45091,
#  'این': 34618,
#  'چترو': 2,
#  'خودم': 19658,
#  'چین': 1310,
#  'اوردم': 856,
#  'ی': 17060,
#  'خیلی': 39475,
#  'خوشگل': 1316,
#  'خاصه': 123,
#  'ک': 5253,
#  'تو': 18443,
#  'بازار': 9026,
#  'نیس': 1489,
#  'و': 578393,
#  'جونداره': 3,
#  'ساتن': 2277,
#  'بنفش': 1375,
#  'رنگ': 129569,
#  'آبی': 3968,
#  'اکبند': 11255,
#  'دانشجویی': 583,
#  'خودکار': 437,
#  'یوروپن': 14,
#  'اصل': 36227,
#  'گوی': 342,
#  'اعصاب': 37,
#  'کاملا': 90476,
#  'تمیز': 135869,
#  'نو': 255043,
#  'کم': 43222,
#  'استفاده': 75785,
#  'شده': 81238,
#  'ترموستات': 184,
#  '900': 353,
#  'در': 172973,
#  'جعبه': 13529,
#  'کولر:موتورژن': 1,
#  '-3500': 1,
#  'دینام': 2776,
#  'کولروماشین': 1,
#  'لباسشویی': 7157,
#  'وارد': 598,
#  'کننده': 15166,
#  'دوربینهای': 59,
#  'اوکای': 1,
#  'ویژن': 342,
#  'زیر': 22398,
#  'قیمت': 126457,
#  'واردات': 318,
#  'دوربین': 20486,
#  'فروش': 128594,
#  'کلی': 3294,
#  'وجزعی': 19,
#  'لطفا': 37550,
#  'قبل': 1156,
#  'تماس': 86912,
#  'گرفتن': 756,
#  'اس': 36409,
#  'ام': 32438,
#  'بدهید': 700,
#  'یو': 3893,
#  'پی': 11015,
#  'سینوسی': 24,
#  'online': 14,
#  'کیفیت': 10239,
#  '1mp': 2,
#  'دیددرشب20m': 1,
#  'دید': 570,
#  'درشب': 53,
#  'AHD': 47,
#  'مارک': 25426,
#  'فابل': 41,
#  'کستل': 17,
#  'چوبی': 12995,
#  'فلزی': 7328,
#  'المان': 2064,
#  'مداد': 216,
#  'رنگی': 5113,
#  'حرفه': 9915,
#  'ای': 68607,
#  '٢٥': 370,
#  'پلی': 6063,
#  'کروم': 314,
#  'دو': 83095,
#  'عدد': 82262,
#  'سی': 29155,
#  '100w': 9,
#  'واقعی': 41709,
#  'تا': 77044,
#  '150': 2847,
#  'هم': 108413,
#  'میرسه': 966,
#  'به': 204109,
#  'شماره': 7762,
#  'tda': 1,
#  '7294': 1,
#  'همراه': 54400,
#  'قطعات': 4031,
#  'بایاسینگ': 1,
#  'نقشه': 1240,
#  'استریو': 469,
#  'مونو': 661,
#  'برای': 58147,
#  'علاقه': 183,
#  'مندان': 60,
#  'ساخت': 8992,
#  'امپلی': 1206,
#  'فایر': 1243,
#  'کاسیو': 892,
#  'میباشد': 40923,
#  'ماشین': 44452,
#  'حساب': 1146,
#  'مهندسی': 554,
#  'بعد': 6125,
#  'خریدن': 475,
#  'پشیمون': 494,
#  'شدم': 961,
#  'نویه': 396,
#  'برا': 4451,
#  'همین': 5273,
#  'میخوام': 7477,
#  'بفروشمش': 2117,
#  'ریموت': 1790,
#  'کنترل': 5768,
#  'چهار': 18896,
#  'کانال': 2585,
#  'باسلام': 13932,
#  'یوپی': 17,
#  '550خودم': 1,
#  'خریدم': 18897,
#  'اصلااستفاده': 367,
#  'نکردم': 3941,
#  'فقط': 131646,
#  'تاییدجوازازاماکن': 1,
#  'خواسته': 101,
#  'بودن': 4817,
#  'من': 6821,
#  '4دوربین': 11,
#  '1دی': 3,
#  'وی': 8934,
#  'ارروش': 1,
#  'نصب': 7273,
#  'کرده': 8107,
#  'بودم': 1496,
#  'باتریشم': 35,
#  'خوبه': 2576,
#  'جواب': 13737,
#  'گونیستم': 31,
#  'ممنون': 16053,
#  'DVRچهار': 3,
#  'کاناله': 317,
#  'شب': 9370,
#  'یکی': 8064,
#  'سقفی': 1003,
#  'تلسکوپی': 140,
#  'هارد': 5916,
#  'یک': 135353,
#  'ترابایت': 543,
#  'گارانتی': 10830,
#  'دار': 34112,
#  'متراژ': 431,
#  '40متر': 15,
#  'منبع': 1089,
#  'تغذیه': 648,
#  'وکلیه': 226,
#  'فیش': 751,
#  'ها': 34682,
#  'اماده': 5811,
#  'بدون': 135980,
#  'کوچک': 7420,
#  'ترین': 3354,
#  'هزینه': 2536,
#  'ست': 13062,
#  'مدار': 441,
#  'بسته': 3578,
#  'فندک': 616,
#  'های': 36272,
#  'اورجینال': 8025,
#  'zippo': 9,
#  'بیش': 1447,
#  '۴۰۰': 525,
#  'مدل': 82486,
#  'حکاکی': 130,
#  'طراحی': 1383,
#  'اسم': 904,
#  'متن': 90,
#  'روی': 12340,
#  'عکس': 19876,
#  'لوگو': 59,
#  'اثر': 846,
#  'انگشت': 989,
#  'تمامی': 5531,
#  'میباشند': 1555,
#  'زیپو': 74,
#  'لوستر': 8304,
#  'سفید': 40838,
#  'وزرد': 79,
#  '220وات': 4,
#  'هزار': 18138,
#  'وپنصد': 3,
#  'تومان': 29272,
#  'پخش': 13401,
#  'لامپ': 2994,
#  'ژله': 2598,
#  'سه': 41996,
#  'مخفی': 702,
#  'شکل': 1326,
#  'آینه': 7285,
#  'گرد': 2584,
#  '-سیلندر': 2,
#  'اپن': 1133,
#  'دکتور': 1,
#  'حرارت': 428,
#  'اعلان': 14,
#  'حریق': 72,
#  'توسط': 1509,
#  'رله': 75,
#  'میتوان': 397,
#  'بسیاری': 86,
#  'وسایل': 12093,
#  'را': 8028,
#  'راه': 5435,
#  'دور': 8333,
#  'کرد': 5077,
#  'مثل': 2258,
#  '۱۲': 2991,
#  'ریموتی': 29,
#  'برق': 3676,
#  'اضطراری': 49,
#  'تک': 22112,
#  'فاز': 1413,
#  'برقی': 12921,
#  'کامپیوتر': 14839,
#  'دستگاه': 33984,
#  'خود': 3627,
#  'پرداز': 10,
#  'دیگر': 3063,
#  'لوازم': 24152,
#  'ضروری': 57,
#  'حد': 95872,
#  'سلام': 61014,
#  '۵': 6129,
#  'توپ': 892,
#  'بلندگو': 690,
#  'دارم': 22482,
#  'هر': 24668,
#  'توپش': 4,
#  '۱۰۰': 1540,
#  'متره$NUMتومان': 1,
#  'بهترین': 7549,
#  'هرچیو': 2,
#  'بخوای': 316,
#  'میتونید': 1961,
#  'باهاش': 1828,
#  'کنید': 9531,
#  'رسم': 104,
#  'نمودار': 32,
#  'نوش': 1441,
#  'بالای': 3431,
#  '٦٠٠': 178,
#  'تومنه': 1456,
#  'casio': 116,
#  'classpad': 4,
#  'plus': 809,
#  '330': 288,
#  'آکبند': 13682,
#  'سیتی': 132,
#  'زن': 2061,
#  'چک': 2506,
#  'کن': 13113,
#  'مادون': 105,
#  'قرمزدیددرشب': 1,
#  'حافظه': 7431,
#  '500گیک': 2,
#  'موس': 2282,
#  'بیست': 2575,
#  'مترسیم': 1,
#  'رسیور': 63,
#  'قابلیت': 8948,
#  'تصویر': 2760,
#  'بر': 3866,
#  'موبایل': 8926,
#  'خریدارواقعی': 2184,
#  'بگیره': 8277,
#  'تخفیف': 102824,
#  'وجودنداره': 3,
#  'مداربسته': 449,
#  'سیماران': 12,
#  'دست': 33581,
#  'دوم': 6682,
#  'اول': 11754,
#  'اشو': 16,
#  'بپرسید': 231,
#  'بخرید': 739,
#  '۱تومنه': 1,
#  '۶': 5907,
#  'ظهر': 1375,
#  'ب': 13030,
#  'algebra': 3,
#  'fx': 48,
#  '2': 24235,
#  '0': 968,
#  'ti-nspire': 1,
#  'cas': 9,
#  'متعلق': 276,
#  'کمپانی': 332,
#  'Texas': 6,
#  'Instruments': 1,
#  'که': 49786,
#  'تولید': 8269,
#  'الکترونیک': 112,
#  'آمریکا': 1316,
#  'است': 32773,
#  'کارهای': 766,
#  'محاسباتی': 5,
#  'فوق': 27089,
#  'پیشرفته': 170,
#  'انجام': 6392,
#  'می': 28662,
#  'دهد': 135,
#  'عبارتی': 16,
#  'نرم': 3138,
#  'افزار': 771,
#  'MATLAB': 2,
#  'متحرک': 1094,
#  'است!': 28,
#  'تازگی': 928,
#  'آورده': 393,
#  'اصلاً': 267,
#  'آن': 3683,
#  'نشده': 46408,
#  '(کامپیوتر)': 10,
#  'چند': 10750,
#  'کاغذ': 1012,
#  'A4': 181,
#  'موجود': 8995,
#  'دوعددترانس': 2,
#  '۱۱۰': 562,
#  'ولت': 556,
#  'ضبطهای': 8,
#  'طبقاتی': 86,
#  'مقطوووووع': 68,
#  'ترانس': 971,
#  'پایه': 14516,
#  'نقاشی': 2405,
#  'ای-کاملا': 5,
#  'تنظیم': 3811,
#  'ارتفاع': 7096,
#  'متناسب': 173,
#  'سایز': 63228,
#  'بوم': 728,
#  'هانگ': 4,
#  'یانگ': 207,
#  'کره': 7851,
#  'BR6': 1,
#  'رنج': 234,
#  '/۵۰': 1,
#  '۲۲۰': 322,
#  'دیجیتال': 5364,
#  'تعدادی': 10245,
#  'تسمه': 3600,
#  'زمینه': 658,
#  'مختلف': 7262,
#  'جمله': 530,
#  'رباتیک': 22,
#  'حدودا': 1410,
#  '100عدد': 73,
#  'متفرقه': 125,
#  'واستپ': 3,
#  'موتور': 35702,
#  'وکنترل': 139,
#  'دورو': 561,
#  'ربات': 54,
#  'تلگرام': 23238,
#  'خدمتیم': 325,
#  'سجاده': 62,
#  'مخمل': 4637,
#  'مناسب': 50341,
#  'جهیزیه': 7817,
#  'یا': 31783,
#  'کادو': 2952,
#  'دادن': 1360,
#  'اندازه': 6679,
#  '٦٥': 90,
#  '١١٠': 305,
#  'تحویل': 8841,
#  'مترو': 1748,
#  'معذورم': 154,
#  'تعداد': 7586,
#  '١': 2415,
#  'مخملی': 370,
#  'قابل': 15571,
#  'توجه': 1754,
#  'تعمیرکاران': 69,
#  'برد': 2455,
#  'فنی': 37182,
#  'مشخص': 1656,
#  'مربوط': 976,
#  'سایدهای': 5,
#  'ایستاده': 3993,
#  'پنلدار': 14,
#  'فکر': 586,
#  'کنم': 3443,
#  'مدلهای': 834,
#  'قدیمیfbb': 1,
#  'نخورده': 4116,
#  'اصلی': 18793,
#  'یخچال': 21594,
#  'فریزر': 12868,
#  'ساید': 1452,
#  'بای': 424,
#  'lg': 478,
#  'دزدگیر': 10882,
#  'اماکن': 94,
#  'برند': 4216,
#  'گلدن': 61,
#  'سیمکارتی': 32,
#  'معمولی': 2161,
#  'کلیه': 6242,
#  'اجزا': 80,
#  'شامل': 4877,
#  'اژیر': 57,
#  'باطری': 9077,
#  'وچشمی': 5,
#  'سیم': 10875,
#  'بی': 19058,
#  'جهت': 13616,
#  'دریافت': 663,
#  'گرفته': 2840,
#  'شود': 6432,
#  'صورت': 14280,
#  'خرید': 16366,
#  'بگیرید': 20992,
#  'تعمیر': 15033,
#  'دقیق': 847,
#  'امریکایی': 1925,
#  'fluke': 3,
#  '75': 925,
#  'series': 46,
#  'مولتیمتر': 2,
#  '3رشته': 3,
#  'تلفن': 6651,
#  '6': 15147,
#  'رشته': 632,
#  'حول': 10,
#  'حوش': 7,
#  '70متر': 7,
#  'بالاترین': 1595,
#  'پیشنهادی': 1778,
#  'بفروش': 13188,
#  'میرسد': 25496,
#  '3عدد': 1045,
#  '110ولت': 11,
#  'همه': 23718,
#  'باهم': 7085,
#  'ولتاژ': 142,
#  '۱۴۰/۱۶۰/۱۸۰': 1,
#  'خروجی': 2840,
#  'ورودی۲۲۰': 1,
#  'مصرفمختلف': 1,
#  'کاهنده': 21,
#  '٣': 2886,
#  'اطلاع': 1034,
#  'مشاهده': 1275,
#  'میکنید': 570,
#  'انها': 194,
#  'هستن': 7086,
#  'کلید': 1236,
#  'پریز': 143,
#  'پنج': 8398,
#  'شیر': 2091,
#  'فرانسوی': 1762,
#  'قطعه': 887,
#  'الکترونیکی': 166,
#  'سخت': 719,
#  'افزاری': 835,
#  'قله': 7,
#  'سنگ': 3790,
#  'بری': 1232,
#  'الکتدونیکی': 1,
#  'اتصال': 2084,
#  'PCمانیتور': 1,
#  '۴': 7318,
#  'میکرو': 568,
#  'فون': 330,
#  'آلارم': 82,
#  'سنسور': 2391,
#  'DVRنو': 1,
#  'باز': 8475,
#  'توانیدبه': 1,
#  'عنوان': 2977,
#  'تلوزیون': 7637,
#  'یامانیتور': 1,
#  'وصل': 1538,
#  'قوطی': 570,
#  'کبریت': 27,
#  'درخدمتم': 2179,
#  'آلبوم': 103,
#  'عروس': 10842,
#  'کدام': 3719,
#  '100': 3823,
#  'قیمتش': 5230,
#  'بیرون': 2089,
#  '300': 1749,
#  'دونه': 7250,
#  'متوسط': 981,
#  'کدوم': 1324,
#  '50': 5562,
#  'نفیس': 250,
#  'وراه': 55,
#  'اندازی': 377,
#  'نقد': 4659,
#  'واقساط': 276,
#  'اقساط': 2283,
#  'بسیار': 78972,
#  '-': 17976,
#  'سبز': 6005,
#  'اسپشیال': 25,
#  'mont': 6,
#  'blanc': 6,
#  'meisterstuck': 1,
#  'ballpen': 1,
#  'مولتی': 593,
#  'برلى': 2,
#  'تشکر': 27775,
#  'سایت': 9882,
#  'دیوار': 42130,
#  'انواع': 20339,
#  'سال': 47775,
#  'گارنتی': 164,
#  'تعویض': 21943,
#  '5000تومان': 102,
#  'نشانه': 37,
#  'گذار': 445,
#  'کتاب': 4764,
#  'نمدی': 528,
#  'پرژکتور': 430,
#  'RGB': 27,
#  '20': 5258,
#  'شدت': 226,
#  'نور': 1461,
#  'رقص': 203,
#  'غیره': 1082,
#  'مصرف': 17564,
#  'اکواریوم': 2622,
#  'ازش': 4532,
#  'میکردم': 255,
#  '10آمپر': 2,
#  'عرض': 6451,
#  'ترانس۲۲۰': 4,
#  'به۱۱۰': 2,
#  'امپیلی': 1579,
#  'بوده': 17139,
#  'باتشکر': 13465,
#  '3303': 2,
#  'اینورتر': 329,
#  'کوتک': 3,
#  '1500': 442,
#  'وات': 4295,
#  'GPS': 206,
#  'گارمین': 9,
#  'oregon': 4,
#  'کیف': 21234,
#  'گیره': 927,
#  'لباس': 39621,
#  'دستی': 9540,
#  'وجعبه': 223,
#  'جی': 18291,
#  'مارشال': 1984,
#  'مدلG502': 1,
#  '45': 1338,
#  '12': 7217,
#  'smd': 28,
#  '3800': 49,
#  'رسد': 3635,
#  '10': 9351,
#  'آمپر': 1223,
#  'واقعی(خودم': 1,
#  'تست': 7691,
#  'کردم': 9688,
#  'واقعیه)': 1,
#  'فن': 2042,
#  'ترمینال(دوتا': 1,
#  'مثبت': 35,
#  'دوتا': 7735,
#  'منفی)': 2,
#  'آداپتور': 419,
#  'سوئیچینگ': 6,
#  'صنعتی': 3432,
#  'ساده': 4020,
#  'طریق': 4104,
#  'تلویزیون': 27142,
#  'صدا': 5330,
#  'رو': 28188,
#  'ضبط': 18000,
#  'وجود': 603,
#  'ندارد': 6781,
#  '15متر': 31,
#  'وآدابتور': 4,
#  'یکسری': 159,
#  'خودنویس': 44,
#  'نوکی': 9,
#  'مانیوسکریبت': 1,
#  'انگلیس': 598,
#  'مربوطه': 448,
#  'MADE': 35,
#  'IN': 63,
#  'ENGLAND': 1,
#  'BY': 5,
#  ':': 6921,
#  'Manuscript': 1,
#  'pen': 22,
#  'company': 5,
#  'ltd': 5,
#  'انگلیسی': 1237,
#  'هست': 38738,
#  'اصلن': 197,
#  'دانشجویان': 154,
#  'کارت': 9840,
#  'DVR': 98,
#  '٨': 1825,
#  'کیلو': 2896,
#  'ناسیونال': 1359,
#  'فراتل': 5,
#  'دلتا': 147,
#  '١٠': 1695,
#  'ساعت': 21638,
#  'کارکرده': 6912,
#  'اند': 1039,
#  'اطلاعات': 4052,
#  '=': 1083,
#  'بیسیم': 1067,
#  'ip': 33,
#  '1080': 64,
#  'مموری': 2728,
#  'خور': 13284,
#  '64': 2314,
#  'Gb': 107,
#  'گوشی': 66741,
#  'صدای': 1997,
#  'طرفه': 374,
#  'جاهای': 130,
#  'متفاوت': 1362,
#  'سیار': 256,
#  'معرکه': 85,
#  'دارد': 29670,
#  'واریس': 20,
#  'طرح': 17635,
#  'متنوع': 1621,
#  '30': 3854,
#  'پیش': 5745,
#  'فوری': 30242,
#  'منجق': 36,
#  'ملیله': 153,
#  'شکسته': 3068,
#  'تزیینی': 3371,
#  'مدلfx-82ES': 2,
#  'مخصوص': 10812,
#  'کنکوری': 219,
#  'سرقیمت': 112,
#  'میام': 8381,
#  'پشت': 9550,
#  'جساب': 3,
#  'fx-4500': 2,
#  'برنامه': 5051,
#  'نویسی': 63,
#  'کارتن': 10224,
#  'دفترچه': 1396,
#  'Techstar': 1,
#  'flight': 3,
#  'computer': 9,
#  'محاسبات': 22,
#  'پروازی': 37,
#  'نایاب': 266,
#  'آک': 9504,
#  'CR3': 2,
#  'راحتی': 23674,
#  'حل': 189,
#  'امتحانات': 22,
#  'سازمان': 49,
#  'سوالی': 734,
#  'داشتین': 360,
#  'واتساپ': 1788,
#  'خدمتم': 3952,
#  'خلبانی': 349,
#  'ته': 321,
#  'بار': 17915,
#  'مونده': 2077,
#  'دلیل': 12928,
#  'گذاشتم': 11718,
#  'فرستادن': 176,
#  'هانزا': 1,
#  'فاراتل': 85,
#  '6کیلو': 21,
#  'چشمک': 44,
#  'آمریکایی': 1911,
#  'تگزازس': 1,
#  'TI-86': 1,
#  'دوباره': 263,
#  'چهارچوب': 116,
#  'دیپ': 26,
#  'وبومهای': 1,
#  'کارشده': 683,
#  'محافظ': 2494,
#  'جان': 557,
#  'ومنیاتوری': 1,
#  'اشنایدر': 22,
#  '(اشنایدر': 1,
#  ')': 4996,
#  'قاب': 13336,
#  'کشویی': 1382,
#  'بعدی': 1014,
#  'کارایی': 420,
#  'ودر': 1575,
#  'سطح': 437,
#  'بالا': 12910,
#  '/': 3853,
#  'ژاپن': 8899,
#  'کدومشو': 16,
#  '170': 599,
#  'الان': 4963,
#  'زیرقیمت': 1289,
#  'میدم': 34570,
#  'ضمن': 2615,
#  'ضمانت': 6317,
#  'تعویضه': 106,
#  '2عدد': 2080,
#  'وتصاویر': 2,
#  'اچ': 4685,
#  'دی': 41912,
#  'سوکت': 1018,
#  'فکس': 977,
#  'مودم': 6330,
#  'تایوانی': 1092,
#  'میرسد$NUMو': 1,
#  'یا$NUM': 19,
#  'زیمنس': 386,
#  '٣٨٠': 52,
#  '٤٠': 1560,
#  'امپر': 722,
#  'DC380/24': 1,
#  '٢٤': 301,
#  'اتوماتیک': 4263,
#  'پُرنیک': 1,
#  'سری': 5945,
#  'Smart': 49,
#  'کارکرد': 17422,
#  'مسئول': 6,
#  'حفاظت': 41,
#  'ارزشمند': 39,
#  'شماست': 176,
#  'شمادر': 2,
#  'برابر': 847,
#  'هرگونه': 942,
#  'کاهش': 257,
#  'افزایش': 381,
#  'محدوده': 795,
#  '۱۴۵': 41,
#  '۲۶۰': 93,
#  'دوفازه': 2,
#  'شدن': 4269,
#  'شهر': 1118,
#  'اختلالات': 2,
#  'فرکانس': 174,
#  'صاعقه': 3,
#  'نویزهای': 2,
#  'می\u200cکند': 24,
#  'تنها': 1570,
#  'مجهز': 854,
#  'حساسیت': 318,
#  'شرایط': 1098,
#  'ورودی': 1709,
#  'نوع': 5180,
#  'می\u200cباشد': 122,
#  'k': 86,
#  'ریزپردازان': 1,
#  'اسمارت': 698,
#  'هنوز': 5243,
#  'پلاستیک': 1192,
#  'ش': 846,
#  'فروشی': 25790,
#  'میدان': 553,
#  'هفت': 17409,
#  'تیر$NUM': 5,
#  'کایسو': 1,
#  'casiuo': 1,
#  'برش': 1953,
#  'دلخواه': 1274,
#  'قالب': 1198,
#  '8': 10678,
#  'متعلقات': 1229,
#  'خرابی': 1249,
#  'آسیب': 495,
#  'دیدگی': 397,
#  'انالوگ': 123,
#  'شرط': 30413,
#  'لازم': 2890,
#  'ندارم': 10766,
#  'میفروشم': 13686,
#  'نمایندگی': 2456,
#  'باکادری': 5,
#  'مجرب': 82,
#  'العاده': 21818,
#  'دارای': 36486,
#  '۳سال': 397,
#  'وسیمکشی': 5,
#  'درضمن': 1729,
#  'محل': 3622,
#  'میشود': 21314,
#  'PLC': 16,
#  'سیگنال': 101,
#  'mgr-0910-me': 2,
#  'حدنو': 2764,
#  'کنار': 8331,
#  'ببخشید': 55,
#  'اگه': 7844,
#  'میشه': 15943,
#  'اگهی': 1051,
#  'دوباه': 2,
#  'کنین': 1073,
#  'سر': 9830,
#  'دوربین٤ماه': 1,
#  'تمام': 31966,
#  'لوازمش': 525,
#  'هاش': 2601,
#  '٣عدد': 252,
#  'دستگاهش': 22,
#  'کارتنش': 309,
#  'توافقی': 9567,
#  'اصلا': 14423,
#  'خوب': 17969,
#  'زدم': 8192,
#  '50000تومان': 197,
#  'موفق': 262,
#  'باشین': 510,
#  '$NUM': 15357,
#  'کابلشو': 16,
#  'ژاپنی': 4191,
#  'حساب(اگر': 1,
#  'پیدا': 1241,
#  'کنید)': 52,
#  'بیشتر': 16109,
#  'هستش': 12888,
#  '٥٠*٧٠': 19,
#  'میز': 101992,
#  'تریستور': 8,
#  'دوبل': 1503,
#  '285': 53,
#  'کاکاتی': 1,
#  '400و': 4,
#  '600': 869,
#  '800': 780,
#  'skkt': 1,
#  'ده': 7748,
#  '7': 11160,
#  'آمپری': 82,
#  'درحد': 18180,
#  'نصف': 3315,
#  'واسه': 6289,
#  'آزمایشی': 10,
#  'گرفتم': 3814,
#  'دوساعت': 175,
#  'ازشون': 386,
#  'ونونو': 104,
#  'خریدار': 34314,
#  'رومیزى': 97,
#  'تحریر': 2851,
#  'تجهیزات': 1629,
#  'منگنه': 223,
#  'جا': 24095,
#  'چسبى': 6,
#  'شارژر': 9922,
#  'کاره': 4447,
#  'آپل': 10,
#  'آندروید': 316,
#  'پاور': 3317,
#  'بانک': 759,
#  'اشانتیون': 1270,
#  '٩٠': 1120,
#  'صورتى': 80,
#  'كه': 191,
#  'مايل': 3,
#  'ديدن': 20,
#  'كليه': 22,
#  'وسايل': 46,
#  'هستيد': 2,
#  'به$NUMتلگرام': 6,
#  'بزنيد': 22,
#  '١١': 470,
#  'تکه': 4043,
#  'سیستم': 10092,
#  'حفاظتی': 28,
#  '15سال': 85,
#  'پیامک': 16933,
#  'بزنید': 4479,
#  'مبدل': 224,
#  'خودرو': 14924,
#  '1000': 1057,
#  'watt': 31,
#  '220': 821,
#  'تبدیل': 1403,
#  'کند': 585,
#  'اصن': 132,
#  'کوهنوردی': 564,
#  'مسافرت': 2532,
#  'خارج': 971,
#  'اما': 4180,
#  'مشکل': 4802,
#  'واسم': 931,
#  'اومد': 245,
#  'ماشینم': 921,
#  'فروختم': 1325,
#  'مبدلش': 5,
#  'باقی': 441,
#  'موند': 76,
#  'جانبی': 4422,
#  'مشخصه': 3791,
#  'انبر': 205,
#  'فندکی': 459,
#  '250': 2406,
#  'بازم': 713,
#  '12ولت': 39,
#  'شهری': 997,
#  '۶kwدرحد': 1,
#  'کلا': 5021,
#  'دوماه': 2020,
#  'جوابگوی': 279,
#  'هستم': 12127,
#  'اتومات': 4616,
#  'نوسانات': 14,
#  'CANON': 56,
#  'حالا': 2440,
#  'گفتم': 2222,
#  'میتونین': 678,
#  'بقیه': 2730,
#  'مقایسه': 873,
#  'کاسیو4500': 1,
#  '4': 20083,
#  'ازظهر': 46,
#  '4500': 125,
#  'لامپو': 1,
#  'نوار': 1080,
#  'ژاپنیه': 36,
#  'حسابداری': 270,
#  'web': 12,
#  'camera': 91,
#  'Web': 12,
#  'camere': 1,
#  'تراش': 2397,
#  'تیغه': 1115,
#  'تیز': 500,
#  'رومیزی': 3236,
#  'دلی': 15,
#  'عددتخته': 5,
#  'نقاله': 137,
#  'دیده': 813,
#  'گونیای': 6,
#  '45×45': 2,
#  'و30×60': 1,
#  'تخته': 5451,
#  'معاوضه': 32207,
#  'قناری': 13899,
#  'ونو': 2658,
#  'کارم': 1159,
#  'نمیادقیمتشوخیلی': 1,
#  'آداک': 10,
#  'صلوات': 27,
#  'شمار': 441,
#  'متبرک': 4,
#  'مشهد': 3144,
#  'یکعدد': 1163,
#  'خازن': 698,
#  'حدود$NUMمیباشد': 5,
#  'تکفاز': 120,
#  'باقدرت': 92,
#  'اسب': 1265,
#  ...}

# %%
dic["که"]
# Out:
# 49786

# %%
import operator
l = []
for a in dic.items():
    if(a[1] > 17000):
        l.append(a)
#     print(str(a[0]) + "        ---------------|        ")
#     print(str(a[1]))
#     print("------------------------------")
# print(l[0])
sortedx = sorted(l, key=lambda tup: tup[1])
for a in range(0, 10):
    print(sortedx[a][0])
    print(sortedx[a][1])
# Out:
# ی
# 17060
# مشتری
# 17073
# بوده
# 17139
# نداره
# 17142
# 5
# 17303
# هفت
# 17409
# کارکرد
# 17422
# مصرف
# 17564
# طرح
# 17635
# برج
# 17783

# %%
 datas.to_csv("phase2.csv", sep=',')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-c5c120f0d202> in <module>
# ----> 1 datas.to_csv("phase2.csv", sep=',')
#
# NameError: name 'datas' is not defined

# %%
print(len(data.cat.unique()))
def probab(treeCat , word):
    a = pd.DataFrame(data, columns=['cat'])
    i=a['cat'].str.contains(treeCat).sum()
    print(i)
    counter = data.loc[data['cat']==(treeCat)]['desc'].str.contains(word).sum()
    print(counter)
    return counter/i
# Out:
# 87

# %%
print(probab("vehicles:cars:light","کمد"))
# Out:
# 120451
# 156
# 0.001295132460502611

# %%
#data.replace([' از ', 'مشتریpoor', 'good', 'نو'],[" ", " ", " ", " ", " "])

# %%
data.drop("cat1", axis=1, inplace=True)
data.drop("cat2", axis=1, inplace=True)
data.drop("cat3", axis=1, inplace=True)
data
# Out:
#         Unnamed: 0  archive_by_user                   brand        city  \
# 34              34            False                     NaN      Tehran
# 99              99            False                     NaN      Tehran
# 164            164             True                     NaN      Tehran
# 619            619            False                     NaN      Tehran
# 710            710            False                     NaN      Tehran
# 1391          1391            False                     NaN      Tehran
# 1432          1432            False                     NaN      Tehran
# 2213          2213             True                     NaN      Tehran
# 3610          3610             True                     NaN     Mashhad
# 3858          3858            False                     NaN      Tehran
# 4557          4557             True                     NaN     Mashhad
# 5081          5081            False                     NaN     Mashhad
# 5152          5152            False                     NaN     Mashhad
# 5493          5493            False                     NaN      Tehran
# 6210          6210            False                     NaN      Tehran
# 6239          6239             True                     NaN      Tehran
# 6443          6443            False                     NaN      Tehran
# 6840          6840            False                     NaN      Tehran
# 7203          7203            False                     NaN      Tehran
# 8229          8229            False                     NaN      Tehran
# 9825          9825            False                     NaN      Tehran
# 9833          9833            False                     NaN      Tehran
# 9841          9841            False                     NaN      Tehran
# 9960          9960            False                     NaN      Tehran
# 10050        10050            False                     NaN      Tehran
# 11485        11485            False                     NaN      Tehran
# 11852        11852            False                     NaN      Tehran
# 12512        12512            False                     NaN      Tehran
# 12548        12548             True                     NaN     Mashhad
# 12823        12823             True                     NaN      Tehran
# ...            ...              ...                     ...         ...
# 947602      947602             True  پراید صندوق‌دار::Pride     Isfahan
# 947604      947604             True                     NaN     Isfahan
# 947605      947605             True                     NaN  Kermanshah
# 947606      947606             True                     NaN     Mashhad
# 947607      947607             True                     NaN      Tehran
# 947608      947608             True                     NaN      Tehran
# 947609      947609             True    پژو ۴۰۵::Peugeot 405      Shiraz
# 947610      947610             True              Apple::اپل      Tehran
# 947611      947611             True                     NaN  Kermanshah
# 947612      947612             True                     NaN      Tehran
# 947613      947613             True                     NaN       Karaj
# 947614      947614             True                     NaN     Isfahan
# 947615      947615             True            سمند::Samand      Shiraz
# 947616      947616             True                     NaN       Ahvaz
# 947617      947617             True                     NaN  Kermanshah
# 947619      947619             True                     NaN      Tehran
# 947620      947620             True                     NaN      Tehran
# 947621      947621             True        Samsung::سامسونگ      Tehran
# 947622      947622             True              Sony::سونی     Mashhad
# 947623      947623             True                     NaN      Tehran
# 947624      947624             True                     NaN      Tehran
# 947625      947625             True  پراید صندوق‌دار::Pride       Karaj
# 947626      947626             True                     NaN       Karaj
# 947627      947627             True                     NaN      Tehran
# 947628      947628             True                     NaN      Tehran
# 947630      947630             True                     NaN      Shiraz
# 947631      947631             True                     NaN      Tehran
# 947632      947632             True  پراید صندوق‌دار::Pride      Shiraz
# 947633      947633             True                     NaN     Mashhad
# 947634      947634             True                     NaN      Shiraz
#
#             created_at                                               desc  \
# 34       Thursday 02AM                        حدود 33 متر کابل مفتولی 4*6
# 99         Sunday 07AM  جنس چتر از ساتنه سایزش بزرگه\nدسته چتر با بدنه...
# 164     Wednesday 01PM                             رنگ آبی اکبند دانشجویی
# 619      Thursday 05PM      گوی اعصاب کاملا تمیز و نو خیلی کم استفاده شده
# 710        Sunday 10AM                        ترموستات 900\nدر جعبه نو نو
# 1391       Monday 03PM                                 کولر:موتورژن -3500
# 1432      Tuesday 09PM    وارد کننده دوربینهای اوکای ویژن زیر قیمت واردات
# 2213    Wednesday 07PM              لطفا قبل از تماس گرفتن اس ام اس بدهید
# 3610       Sunday 11PM                              کیفیت 1mp\nدیددرشب20m
# 3858       Friday 09AM   مارک فابل کستل \nبا جعبه چوبی و فلزی \nاصل المان
# 4557    Wednesday 04PM  دو عدد ای سی 100w واقعی و تا 150 هم میرسه به ش...
# 5081       Friday 01AM                                   کاسیو ،نو میباشد
# 5152       Sunday 11AM  بعد از خریدن پشیمون شدم و کاملا نویه برا همین ...
# 5493     Thursday 10AM  باسلام این یوپی اس  550خودم خریدم اصلااستفاده ...
# 6210     Saturday 08PM  DVRچهار کاناله \nدو دوربین دید در شب یکی سقفی ...
# 6239       Sunday 05PM  فندک های اورجینال zippo با بیش از ۴۰۰ مدل\nحکا...
# 6443     Saturday 03PM           لوستر سفید وزرد  220وات هزار وپنصد تومان
# 6840     Saturday 03PM  سه عدد دوربین مخفی به شکل آینه گرد -سیلندر لام...
# 7203     Saturday 02PM  توسط این رله میتوان بسیاری از وسایل را از راه ...
# 8229     Thursday 02PM  فروش یو پی اس برق اضطراری \nتک فاز و سه فاز \n...
# 9825     Thursday 04PM                              کاملا سالم و در حد نو
# 9833     Thursday 06PM  سلام ۵ توپ کابل بلندگو دارم هر توپش ۱۰۰ متره$N...
# 9841       Friday 05AM  ماشین حساب مهندسی \nبهترین مدل کاسیو \nهرچیو ک...
# 9960      Tuesday 05PM                               آکبند زیر قیمت بازار
# 10050      Friday 05PM  یک عدد دوربین مادون قرمزدیددرشب.حافظه 500گیک ....
# 11485      Friday 01PM  ماشین حساب دست دوم کم کار کرده اول نو اشو بپرس...
# 11852      Friday 08AM  کامپیوتر مهندسی ti-nspire cas متعلق به کمپانی ...
# 12512      Monday 04PM                        چند بسته کاغذ A4 موجود است.
# 12548     Tuesday 08AM  دوعددترانس ۱۱۰ ولت برای ضبطهای طبقاتی.سالم.قیم...
# 12823      Sunday 11AM  سه پایه نقاشی حرفه ای-کاملا سالم\nقابلیت تنظیم...
# ...                ...                                                ...
# 947602    Tuesday 05PM  مدل 84 تمیز. بدون رنگ. سیستم صوتی. رینگ و لاست...
# 947604    Tuesday 05PM  با سلام \nمبلمان هفت نفره و همانطور که تو عکس ...
# 947605    Tuesday 07PM  سلام تلویزیون درحد نوو تمیز دیجیتال دار تخفیف ...
# 947606    Tuesday 09PM                    بخاری آلیش گاز تمیز\nسالم ومرتب
# 947607  Wednesday 05AM  تولیدی صنایع چوبی فریدپور تولید کننده انواع مب...
# 947608  Wednesday 07AM  همه نو وسالم استفاده نشده چند وقت پیش از نماین...
# 947609  Wednesday 08AM  ۴۰۵slxیا همان tufصفر کیلومتر سند خورده تحویل د...
# 947610  Wednesday 11AM      جعبه ولوازم LLAاصل/بدون خط وخش/باز نشده/سالم.
# 947611  Wednesday 11AM  بلندی 2 متر پنها 1 متر عمق 40 ثانت\nچهار طبقه ...
# 947612  Wednesday 03PM  بادسان فوق بیرنگ سفید رنگ بیمه تابرج 3.96 تخفی...
# 947613  Wednesday 05PM                                   4نفره تمیز سبک .
# 947614  Wednesday 06PM  باسلام .تراکتورازصفری دست خودم بوده.سالم.ودارا...
# 947615  Wednesday 06PM      ماشینم تصادفیه با خریدار توافق میکنم سر قیمتش
# 947616   Thursday 04AM                سلام.کاملا اکبند هستش،و هیچ نپوشیدم
# 947617   Thursday 04AM  انواع گلهای کریستالی،توری،تل وگیرژله ای سفارش ...
# 947619   Thursday 07AM  مبل ٩ نفره همراه با میز وسط و یک عدد عسلی مبلم...
# 947620   Thursday 08AM  مبلمان هفت نفره شیک و تمیز همراه با میز جلویی ...
# 947621   Thursday 09AM  سالم و تمیز با لوازم\nاندروید 5. باتری اورجینا...
# 947622   Thursday 11AM  فروش یا معاوضه فوری فوری\nسفید تمیز همراه با گ...
# 947623   Thursday 11AM  فروش دو عدد دستگاه بلوک زنی (لیکا)\n15*20*40\n...
# 947624   Thursday 12PM  صندلی کودک مارک چیکو دقیقا مدل و رنگ دز دیوار ...
# 947625   Thursday 03PM  سند۲ برگ،بیمه تا برج$NUMتخفیفات بیمه 15 سال،مع...
# 947626   Thursday 05PM  با سلام خدمت شما \nاین دستگاه تمیزه سالمه ۲۴۰۰...
# 947627   Thursday 05PM  بهتوین زودپزه اگه کسی بشناسه\nبه علت جا به جای...
# 947628   Thursday 05PM                       با دوسال ضمانت تشکر از دیوار
# 947630     Friday 07AM  دوعدد یکی یک متری و دیگری 1.4 متری موجود است\n...
# 947631     Friday 02PM  دوربین هندی کم کنون مدل لگریا fs36\n\nعکاسی و ...
# 947632     Friday 04PM  پراید دوگانه کارخانه میباشد و کم کارکرد.روکش ....
# 947633     Friday 05PM  مونو پد یانگ تد همراه با پایه و اینه عقبش\nواس...
# 947634     Friday 05PM                           جواب فقط تماس و. وات ساپ
#
#                     id  image_count   mileage platform     price  \
# 34       1137276559195            3       NaN   mobile        -1
# 99       3748386024591            2       NaN   mobile     15000
# 164     22187152508462            2       NaN   mobile     20000
# 619     60619246221783            2       NaN   mobile     40000
# 710     19665758010091            2       NaN   mobile        -1
# 1391    22419836618997            0       NaN   mobile        -1
# 1432    19115305930834            5       NaN   mobile     60000
# 2213     3976462757088            3       NaN      web        -1
# 3610    57878037736511            0       NaN   mobile     49000
# 3858    12929847977570            2       NaN   mobile    120000
# 4557    60113808781871            4       NaN   mobile     25900
# 5081    10393372789619            0       NaN   mobile     50000
# 5152    25972186067577            1       NaN   mobile     38000
# 5493    14824526811749            3       NaN   mobile    450000
# 6210    10150494389916            1       NaN   mobile    600000
# 6239    47213808326153            4       NaN   mobile        -1
# 6443    60012789528305            2       NaN   mobile     15000
# 6840    23628200341143            1       NaN      web    150000
# 7203    36608778124251            1       NaN   mobile     80000
# 8229    54035060696775            1       NaN   mobile        -1
# 9825    61814958412348            1       NaN   mobile        -1
# 9833     9184129444572            1       NaN   mobile    170000
# 9841      187613148903            1       NaN   mobile    370000
# 9960    38601155211481            4       NaN   mobile     27000
# 10050   45325197233498            4       NaN   mobile    350000
# 11485   59656433072680            1       NaN   mobile    637000
# 11852    7473964742684            1       NaN      web    700000
# 12512   28828383200715            2       NaN   mobile      9000
# 12548   55378933610643            0       NaN   mobile    100000
# 12823    2086301919390            2       NaN      web    100000
# ...                ...          ...       ...      ...       ...
# 947602  36679901713761            3  140000.0   mobile  11000000
# 947604  24085275306660            3       NaN   mobile        -1
# 947605  11663382531270            1       NaN   mobile    650000
# 947606   1612990731772            3       NaN   mobile     90000
# 947607  33249797540027            1       NaN   mobile    680000
# 947608  36285186767743            2       NaN   mobile    250000
# 947609  30077906536153            3       1.0   mobile        -1
# 947610    132753009802            2       NaN   mobile    720000
# 947611  61466620806128            1       NaN   mobile    150000
# 947612  21866530196097            2       NaN   mobile  48000000
# 947613   6518293923049            2       NaN   mobile    150000
# 947614  44067752978166            4       NaN   mobile        -1
# 947615  32248935135739            3   20000.0      web        -1
# 947616  53252710020814            1       NaN   mobile        -1
# 947617  63799201859273            2       NaN   mobile     35000
# 947619  53006184204970            1       NaN   mobile    400000
# 947620  64279503963911            3       NaN   mobile        -1
# 947621  20251684311504            2       NaN   mobile    475000
# 947622  48122459746674            0       NaN      web    650000
# 947623  15026572391599            1       NaN      web        -1
# 947624   6072997698913            1       NaN   mobile    180000
# 947625  30197850752025            4  123000.0   mobile   6900000
# 947626  30247035759677            2       NaN   mobile        -1
# 947627  12624632523188            3       NaN   mobile    350000
# 947628  38646519610598            5       NaN   mobile   2200000
# 947630  16127180351093            1       NaN      web    180000
# 947631  29805298491725            1       NaN   mobile    350000
# 947632  55514317985619            3   43000.0   mobile  17400000
# 947633  65938921533442            1       NaN   mobile     40000
# 947634  18312774360687            1       NaN   mobile     25000
#
#                                        title type  year  \
# 34              کابل 4*6 خشک سالم کار نکرده.  NaN   NaN
# 99                             چتر ساتن بنفش  NaN   NaN
# 164                        خودکار یوروپن اصل  NaN   NaN
# 619                                گوی اعصاب  NaN   NaN
# 710                             ترموستات 900  NaN   NaN
# 1391               دینام کولروماشین لباسشویی  NaN   NaN
# 1432                   دوربین فروش کلی وجزعی  NaN   NaN
# 2213                  یو پی اس سینوسی online  NaN   NaN
# 3610                     دوربین دید درشب AHD  NaN   NaN
# 3858       مداد رنگی حرفه ای ٢٥ رنگ پلی کروم  NaN   NaN
# 4557                   ای سی 100w امپلی فایر  NaN   NaN
# 5081               ماشین حساب مهندسی،حرفه ای  NaN   NaN
# 5152               ریموت کنترل چهار کانال نو  NaN   NaN
# 5493                                 یوپی اس  NaN   NaN
# 6210                     ست دوربین مدار بسته  NaN   NaN
# 6239                  فندک های اورجینال زیپو  NaN   NaN
# 6443                      پخش لامپ ها ژله ای  NaN   NaN
# 6840                         دوربین     مخفی  NaN   NaN
# 7203                     رله ۱۲ کانال ریموتی  NaN   NaN
# 8229               فروش یو پی اس برق اضطراری  NaN   NaN
# 9825                        ماشین حساب کاسیو  NaN   NaN
# 9833                             کابل بلندگو  NaN   NaN
# 9841    ماشین حساب   casio classpad plus 330  NaN   NaN
# 9960         ماشین حساب آکبند ،سیتی زن،چک کن  NaN   NaN
# 10050              دوربین مداربسته .سیماران.  NaN   NaN
# 11485         ماشین حساب algebra fx 2.0 plus  NaN   NaN
# 11852           ماشین حساب (کامپیوتر) مهندسی  NaN   NaN
# 12512                                کاغذ A4  NaN   NaN
# 12548                          ترانس ۱۱۰ ولت  NaN   NaN
# 12823                          سه پایه نقاشی  NaN   NaN
# ...                                      ...  ...   ...
# 947602                 پراید مدل 84 بدون رنگ  NaN  1384
# 947604                 مبل راحتی فروش توافقی  NaN   NaN
# 947605                   تلویزیون ال ای دی32  NaN   NaN
# 947606                   بخاری آلیش گاز تمیز  NaN   NaN
# 947607                         غذاخوری 4نفره  NaN   NaN
# 947608                          ظروف لوردشید  NaN   NaN
# 947609                                ۴۰۵slx  NaN  1395
# 947610                         /١٦gig/5s/گلد  NaN   NaN
# 947611                ویترین ایستاده در حدنو  NaN   NaN
# 947612                     بادسان 8b14 مدل83  NaN   NaN
# 947613          میز نهارخوری4نفره بسیار تمیز  NaN   NaN
# 947614              تراکتورگلدونی ۲۳۸ایتالیا  NaN   NaN
# 947615               خودرو سمند تصادفی مدل92  NaN  1392
# 947616               لباس و اورکت ارتش نو نو  men   NaN
# 947617                           گل کریستالی  NaN   NaN
# 947619                      مبل راحتی ٩ نفره  NaN   NaN
# 947620                       مبلمان هفت نفره  NaN   NaN
# 947621                 گلکسی galaxy s4 i9500  NaN   NaN
# 947622                سونی Z2فورجی سفیدD6503  NaN   NaN
# 947623       دستگاه بلوک زنی (لیکا) - دو عدد  NaN   NaN
# 947624                            صندلی کودک  NaN   NaN
# 947625                   پراید 79 بسیار سالم  NaN  1379
# 947626                      ظبط سه دیسک آیوا  NaN   NaN
# 947627                     زودپز کلیپسو تفال  NaN   NaN
# 947628                           تولید کننده  NaN   NaN
# 947630                  رادیاتور پنلی نو ترک  NaN   NaN
# 947631                  دوربین هندی کم  کنون  NaN   NaN
# 947632            پراید دوگانه کارخانه مدل93  NaN  1393
# 947633         مونوپد یانگ تد خیلی تمیز و نو  NaN   NaN
# 947634                             ساعت مارک  NaN   NaN
#
#                                                       cat
# 34                                     electronic-devices
# 99                                               personal
# 164                                              personal
# 619                                              personal
# 710                                    electronic-devices
# 1391                                   electronic-devices
# 1432                                   electronic-devices
# 2213                                   electronic-devices
# 3610                                   electronic-devices
# 3858                                             personal
# 4557                                   electronic-devices
# 5081                                   electronic-devices
# 5152                                   electronic-devices
# 5493                                   electronic-devices
# 6210                                   electronic-devices
# 6239                                             personal
# 6443                                   electronic-devices
# 6840                                   electronic-devices
# 7203                                   electronic-devices
# 8229                                   electronic-devices
# 9825                                   electronic-devices
# 9833                                   electronic-devices
# 9841                                   electronic-devices
# 9960                                   electronic-devices
# 10050                                  electronic-devices
# 11485                                  electronic-devices
# 11852                                  electronic-devices
# 12512                                            personal
# 12548                                  electronic-devices
# 12823                                            personal
# ...                                                   ...
# 947602                                vehicles:cars:light
# 947604  for-the-home:furniture-and-home-decore:sofa-ar...
# 947605        electronic-devices:audio-video:tv-projector
# 947606  for-the-home:building-and-garden:stove-and-hea...
# 947607  for-the-home:furniture-and-home-decore:tables-...
# 947608  for-the-home:utensils-and-appliances:cookware-...
# 947609                                vehicles:cars:light
# 947610     electronic-devices:mobile-tablet:mobile-phones
# 947611  businesses:equipments-and-machinery:shop-and-cash
# 947612                                vehicles:cars:heavy
# 947613  for-the-home:furniture-and-home-decore:tables-...
# 947614                                vehicles:cars:heavy
# 947615                                vehicles:cars:light
# 947616               personal:clothing-and-shoes:clothing
# 947617  for-the-home:furniture-and-home-decore:antique...
# 947619  for-the-home:furniture-and-home-decore:sofa-ar...
# 947620  for-the-home:furniture-and-home-decore:sofa-ar...
# 947621     electronic-devices:mobile-tablet:mobile-phones
# 947622     electronic-devices:mobile-tablet:mobile-phones
# 947623     businesses:equipments-and-machinery:industrial
# 947624              personal:baby-and-toys:child-car-seat
# 947625                                vehicles:cars:light
# 947626     electronic-devices:audio-video:stereo-surround
# 947627  for-the-home:utensils-and-appliances:cookware-...
# 947628  for-the-home:furniture-and-home-decore:sofa-ar...
# 947630  for-the-home:building-and-garden:stove-and-hea...
# 947631    electronic-devices:audio-video:camera-camcoders
# 947632                                vehicles:cars:light
# 947633  electronic-devices:mobile-tablet:mobile-tablet...
# 947634               personal:jewelry-and-watches:watches
#
# [947635 rows x 15 columns]

# %%
data['cat1'], data['cat2'], data['cat3'] = data['cat'].str.split(':', 2).str
data
# Out:
#         Unnamed: 0  archive_by_user                   brand        city  \
# 34              34            False                     NaN      Tehran
# 99              99            False                     NaN      Tehran
# 164            164             True                     NaN      Tehran
# 619            619            False                     NaN      Tehran
# 710            710            False                     NaN      Tehran
# 1391          1391            False                     NaN      Tehran
# 1432          1432            False                     NaN      Tehran
# 2213          2213             True                     NaN      Tehran
# 3610          3610             True                     NaN     Mashhad
# 3858          3858            False                     NaN      Tehran
# 4557          4557             True                     NaN     Mashhad
# 5081          5081            False                     NaN     Mashhad
# 5152          5152            False                     NaN     Mashhad
# 5493          5493            False                     NaN      Tehran
# 6210          6210            False                     NaN      Tehran
# 6239          6239             True                     NaN      Tehran
# 6443          6443            False                     NaN      Tehran
# 6840          6840            False                     NaN      Tehran
# 7203          7203            False                     NaN      Tehran
# 8229          8229            False                     NaN      Tehran
# 9825          9825            False                     NaN      Tehran
# 9833          9833            False                     NaN      Tehran
# 9841          9841            False                     NaN      Tehran
# 9960          9960            False                     NaN      Tehran
# 10050        10050            False                     NaN      Tehran
# 11485        11485            False                     NaN      Tehran
# 11852        11852            False                     NaN      Tehran
# 12512        12512            False                     NaN      Tehran
# 12548        12548             True                     NaN     Mashhad
# 12823        12823             True                     NaN      Tehran
# ...            ...              ...                     ...         ...
# 947602      947602             True  پراید صندوق‌دار::Pride     Isfahan
# 947604      947604             True                     NaN     Isfahan
# 947605      947605             True                     NaN  Kermanshah
# 947606      947606             True                     NaN     Mashhad
# 947607      947607             True                     NaN      Tehran
# 947608      947608             True                     NaN      Tehran
# 947609      947609             True    پژو ۴۰۵::Peugeot 405      Shiraz
# 947610      947610             True              Apple::اپل      Tehran
# 947611      947611             True                     NaN  Kermanshah
# 947612      947612             True                     NaN      Tehran
# 947613      947613             True                     NaN       Karaj
# 947614      947614             True                     NaN     Isfahan
# 947615      947615             True            سمند::Samand      Shiraz
# 947616      947616             True                     NaN       Ahvaz
# 947617      947617             True                     NaN  Kermanshah
# 947619      947619             True                     NaN      Tehran
# 947620      947620             True                     NaN      Tehran
# 947621      947621             True        Samsung::سامسونگ      Tehran
# 947622      947622             True              Sony::سونی     Mashhad
# 947623      947623             True                     NaN      Tehran
# 947624      947624             True                     NaN      Tehran
# 947625      947625             True  پراید صندوق‌دار::Pride       Karaj
# 947626      947626             True                     NaN       Karaj
# 947627      947627             True                     NaN      Tehran
# 947628      947628             True                     NaN      Tehran
# 947630      947630             True                     NaN      Shiraz
# 947631      947631             True                     NaN      Tehran
# 947632      947632             True  پراید صندوق‌دار::Pride      Shiraz
# 947633      947633             True                     NaN     Mashhad
# 947634      947634             True                     NaN      Shiraz
#
#             created_at                                               desc  \
# 34       Thursday 02AM                        حدود 33 متر کابل مفتولی 4*6
# 99         Sunday 07AM  جنس چتر از ساتنه سایزش بزرگه\nدسته چتر با بدنه...
# 164     Wednesday 01PM                             رنگ آبی اکبند دانشجویی
# 619      Thursday 05PM      گوی اعصاب کاملا تمیز و نو خیلی کم استفاده شده
# 710        Sunday 10AM                        ترموستات 900\nدر جعبه نو نو
# 1391       Monday 03PM                                 کولر:موتورژن -3500
# 1432      Tuesday 09PM    وارد کننده دوربینهای اوکای ویژن زیر قیمت واردات
# 2213    Wednesday 07PM              لطفا قبل از تماس گرفتن اس ام اس بدهید
# 3610       Sunday 11PM                              کیفیت 1mp\nدیددرشب20m
# 3858       Friday 09AM   مارک فابل کستل \nبا جعبه چوبی و فلزی \nاصل المان
# 4557    Wednesday 04PM  دو عدد ای سی 100w واقعی و تا 150 هم میرسه به ش...
# 5081       Friday 01AM                                   کاسیو ،نو میباشد
# 5152       Sunday 11AM  بعد از خریدن پشیمون شدم و کاملا نویه برا همین ...
# 5493     Thursday 10AM  باسلام این یوپی اس  550خودم خریدم اصلااستفاده ...
# 6210     Saturday 08PM  DVRچهار کاناله \nدو دوربین دید در شب یکی سقفی ...
# 6239       Sunday 05PM  فندک های اورجینال zippo با بیش از ۴۰۰ مدل\nحکا...
# 6443     Saturday 03PM           لوستر سفید وزرد  220وات هزار وپنصد تومان
# 6840     Saturday 03PM  سه عدد دوربین مخفی به شکل آینه گرد -سیلندر لام...
# 7203     Saturday 02PM  توسط این رله میتوان بسیاری از وسایل را از راه ...
# 8229     Thursday 02PM  فروش یو پی اس برق اضطراری \nتک فاز و سه فاز \n...
# 9825     Thursday 04PM                              کاملا سالم و در حد نو
# 9833     Thursday 06PM  سلام ۵ توپ کابل بلندگو دارم هر توپش ۱۰۰ متره$N...
# 9841       Friday 05AM  ماشین حساب مهندسی \nبهترین مدل کاسیو \nهرچیو ک...
# 9960      Tuesday 05PM                               آکبند زیر قیمت بازار
# 10050      Friday 05PM  یک عدد دوربین مادون قرمزدیددرشب.حافظه 500گیک ....
# 11485      Friday 01PM  ماشین حساب دست دوم کم کار کرده اول نو اشو بپرس...
# 11852      Friday 08AM  کامپیوتر مهندسی ti-nspire cas متعلق به کمپانی ...
# 12512      Monday 04PM                        چند بسته کاغذ A4 موجود است.
# 12548     Tuesday 08AM  دوعددترانس ۱۱۰ ولت برای ضبطهای طبقاتی.سالم.قیم...
# 12823      Sunday 11AM  سه پایه نقاشی حرفه ای-کاملا سالم\nقابلیت تنظیم...
# ...                ...                                                ...
# 947602    Tuesday 05PM  مدل 84 تمیز. بدون رنگ. سیستم صوتی. رینگ و لاست...
# 947604    Tuesday 05PM  با سلام \nمبلمان هفت نفره و همانطور که تو عکس ...
# 947605    Tuesday 07PM  سلام تلویزیون درحد نوو تمیز دیجیتال دار تخفیف ...
# 947606    Tuesday 09PM                    بخاری آلیش گاز تمیز\nسالم ومرتب
# 947607  Wednesday 05AM  تولیدی صنایع چوبی فریدپور تولید کننده انواع مب...
# 947608  Wednesday 07AM  همه نو وسالم استفاده نشده چند وقت پیش از نماین...
# 947609  Wednesday 08AM  ۴۰۵slxیا همان tufصفر کیلومتر سند خورده تحویل د...
# 947610  Wednesday 11AM      جعبه ولوازم LLAاصل/بدون خط وخش/باز نشده/سالم.
# 947611  Wednesday 11AM  بلندی 2 متر پنها 1 متر عمق 40 ثانت\nچهار طبقه ...
# 947612  Wednesday 03PM  بادسان فوق بیرنگ سفید رنگ بیمه تابرج 3.96 تخفی...
# 947613  Wednesday 05PM                                   4نفره تمیز سبک .
# 947614  Wednesday 06PM  باسلام .تراکتورازصفری دست خودم بوده.سالم.ودارا...
# 947615  Wednesday 06PM      ماشینم تصادفیه با خریدار توافق میکنم سر قیمتش
# 947616   Thursday 04AM                سلام.کاملا اکبند هستش،و هیچ نپوشیدم
# 947617   Thursday 04AM  انواع گلهای کریستالی،توری،تل وگیرژله ای سفارش ...
# 947619   Thursday 07AM  مبل ٩ نفره همراه با میز وسط و یک عدد عسلی مبلم...
# 947620   Thursday 08AM  مبلمان هفت نفره شیک و تمیز همراه با میز جلویی ...
# 947621   Thursday 09AM  سالم و تمیز با لوازم\nاندروید 5. باتری اورجینا...
# 947622   Thursday 11AM  فروش یا معاوضه فوری فوری\nسفید تمیز همراه با گ...
# 947623   Thursday 11AM  فروش دو عدد دستگاه بلوک زنی (لیکا)\n15*20*40\n...
# 947624   Thursday 12PM  صندلی کودک مارک چیکو دقیقا مدل و رنگ دز دیوار ...
# 947625   Thursday 03PM  سند۲ برگ،بیمه تا برج$NUMتخفیفات بیمه 15 سال،مع...
# 947626   Thursday 05PM  با سلام خدمت شما \nاین دستگاه تمیزه سالمه ۲۴۰۰...
# 947627   Thursday 05PM  بهتوین زودپزه اگه کسی بشناسه\nبه علت جا به جای...
# 947628   Thursday 05PM                       با دوسال ضمانت تشکر از دیوار
# 947630     Friday 07AM  دوعدد یکی یک متری و دیگری 1.4 متری موجود است\n...
# 947631     Friday 02PM  دوربین هندی کم کنون مدل لگریا fs36\n\nعکاسی و ...
# 947632     Friday 04PM  پراید دوگانه کارخانه میباشد و کم کارکرد.روکش ....
# 947633     Friday 05PM  مونو پد یانگ تد همراه با پایه و اینه عقبش\nواس...
# 947634     Friday 05PM                           جواب فقط تماس و. وات ساپ
#
#                     id  image_count   mileage platform     price  \
# 34       1137276559195            3       NaN   mobile        -1
# 99       3748386024591            2       NaN   mobile     15000
# 164     22187152508462            2       NaN   mobile     20000
# 619     60619246221783            2       NaN   mobile     40000
# 710     19665758010091            2       NaN   mobile        -1
# 1391    22419836618997            0       NaN   mobile        -1
# 1432    19115305930834            5       NaN   mobile     60000
# 2213     3976462757088            3       NaN      web        -1
# 3610    57878037736511            0       NaN   mobile     49000
# 3858    12929847977570            2       NaN   mobile    120000
# 4557    60113808781871            4       NaN   mobile     25900
# 5081    10393372789619            0       NaN   mobile     50000
# 5152    25972186067577            1       NaN   mobile     38000
# 5493    14824526811749            3       NaN   mobile    450000
# 6210    10150494389916            1       NaN   mobile    600000
# 6239    47213808326153            4       NaN   mobile        -1
# 6443    60012789528305            2       NaN   mobile     15000
# 6840    23628200341143            1       NaN      web    150000
# 7203    36608778124251            1       NaN   mobile     80000
# 8229    54035060696775            1       NaN   mobile        -1
# 9825    61814958412348            1       NaN   mobile        -1
# 9833     9184129444572            1       NaN   mobile    170000
# 9841      187613148903            1       NaN   mobile    370000
# 9960    38601155211481            4       NaN   mobile     27000
# 10050   45325197233498            4       NaN   mobile    350000
# 11485   59656433072680            1       NaN   mobile    637000
# 11852    7473964742684            1       NaN      web    700000
# 12512   28828383200715            2       NaN   mobile      9000
# 12548   55378933610643            0       NaN   mobile    100000
# 12823    2086301919390            2       NaN      web    100000
# ...                ...          ...       ...      ...       ...
# 947602  36679901713761            3  140000.0   mobile  11000000
# 947604  24085275306660            3       NaN   mobile        -1
# 947605  11663382531270            1       NaN   mobile    650000
# 947606   1612990731772            3       NaN   mobile     90000
# 947607  33249797540027            1       NaN   mobile    680000
# 947608  36285186767743            2       NaN   mobile    250000
# 947609  30077906536153            3       1.0   mobile        -1
# 947610    132753009802            2       NaN   mobile    720000
# 947611  61466620806128            1       NaN   mobile    150000
# 947612  21866530196097            2       NaN   mobile  48000000
# 947613   6518293923049            2       NaN   mobile    150000
# 947614  44067752978166            4       NaN   mobile        -1
# 947615  32248935135739            3   20000.0      web        -1
# 947616  53252710020814            1       NaN   mobile        -1
# 947617  63799201859273            2       NaN   mobile     35000
# 947619  53006184204970            1       NaN   mobile    400000
# 947620  64279503963911            3       NaN   mobile        -1
# 947621  20251684311504            2       NaN   mobile    475000
# 947622  48122459746674            0       NaN      web    650000
# 947623  15026572391599            1       NaN      web        -1
# 947624   6072997698913            1       NaN   mobile    180000
# 947625  30197850752025            4  123000.0   mobile   6900000
# 947626  30247035759677            2       NaN   mobile        -1
# 947627  12624632523188            3       NaN   mobile    350000
# 947628  38646519610598            5       NaN   mobile   2200000
# 947630  16127180351093            1       NaN      web    180000
# 947631  29805298491725            1       NaN   mobile    350000
# 947632  55514317985619            3   43000.0   mobile  17400000
# 947633  65938921533442            1       NaN   mobile     40000
# 947634  18312774360687            1       NaN   mobile     25000
#
#                                        title type  year  \
# 34              کابل 4*6 خشک سالم کار نکرده.  NaN   NaN
# 99                             چتر ساتن بنفش  NaN   NaN
# 164                        خودکار یوروپن اصل  NaN   NaN
# 619                                گوی اعصاب  NaN   NaN
# 710                             ترموستات 900  NaN   NaN
# 1391               دینام کولروماشین لباسشویی  NaN   NaN
# 1432                   دوربین فروش کلی وجزعی  NaN   NaN
# 2213                  یو پی اس سینوسی online  NaN   NaN
# 3610                     دوربین دید درشب AHD  NaN   NaN
# 3858       مداد رنگی حرفه ای ٢٥ رنگ پلی کروم  NaN   NaN
# 4557                   ای سی 100w امپلی فایر  NaN   NaN
# 5081               ماشین حساب مهندسی،حرفه ای  NaN   NaN
# 5152               ریموت کنترل چهار کانال نو  NaN   NaN
# 5493                                 یوپی اس  NaN   NaN
# 6210                     ست دوربین مدار بسته  NaN   NaN
# 6239                  فندک های اورجینال زیپو  NaN   NaN
# 6443                      پخش لامپ ها ژله ای  NaN   NaN
# 6840                         دوربین     مخفی  NaN   NaN
# 7203                     رله ۱۲ کانال ریموتی  NaN   NaN
# 8229               فروش یو پی اس برق اضطراری  NaN   NaN
# 9825                        ماشین حساب کاسیو  NaN   NaN
# 9833                             کابل بلندگو  NaN   NaN
# 9841    ماشین حساب   casio classpad plus 330  NaN   NaN
# 9960         ماشین حساب آکبند ،سیتی زن،چک کن  NaN   NaN
# 10050              دوربین مداربسته .سیماران.  NaN   NaN
# 11485         ماشین حساب algebra fx 2.0 plus  NaN   NaN
# 11852           ماشین حساب (کامپیوتر) مهندسی  NaN   NaN
# 12512                                کاغذ A4  NaN   NaN
# 12548                          ترانس ۱۱۰ ولت  NaN   NaN
# 12823                          سه پایه نقاشی  NaN   NaN
# ...                                      ...  ...   ...
# 947602                 پراید مدل 84 بدون رنگ  NaN  1384
# 947604                 مبل راحتی فروش توافقی  NaN   NaN
# 947605                   تلویزیون ال ای دی32  NaN   NaN
# 947606                   بخاری آلیش گاز تمیز  NaN   NaN
# 947607                         غذاخوری 4نفره  NaN   NaN
# 947608                          ظروف لوردشید  NaN   NaN
# 947609                                ۴۰۵slx  NaN  1395
# 947610                         /١٦gig/5s/گلد  NaN   NaN
# 947611                ویترین ایستاده در حدنو  NaN   NaN
# 947612                     بادسان 8b14 مدل83  NaN   NaN
# 947613          میز نهارخوری4نفره بسیار تمیز  NaN   NaN
# 947614              تراکتورگلدونی ۲۳۸ایتالیا  NaN   NaN
# 947615               خودرو سمند تصادفی مدل92  NaN  1392
# 947616               لباس و اورکت ارتش نو نو  men   NaN
# 947617                           گل کریستالی  NaN   NaN
# 947619                      مبل راحتی ٩ نفره  NaN   NaN
# 947620                       مبلمان هفت نفره  NaN   NaN
# 947621                 گلکسی galaxy s4 i9500  NaN   NaN
# 947622                سونی Z2فورجی سفیدD6503  NaN   NaN
# 947623       دستگاه بلوک زنی (لیکا) - دو عدد  NaN   NaN
# 947624                            صندلی کودک  NaN   NaN
# 947625                   پراید 79 بسیار سالم  NaN  1379
# 947626                      ظبط سه دیسک آیوا  NaN   NaN
# 947627                     زودپز کلیپسو تفال  NaN   NaN
# 947628                           تولید کننده  NaN   NaN
# 947630                  رادیاتور پنلی نو ترک  NaN   NaN
# 947631                  دوربین هندی کم  کنون  NaN   NaN
# 947632            پراید دوگانه کارخانه مدل93  NaN  1393
# 947633         مونوپد یانگ تد خیلی تمیز و نو  NaN   NaN
# 947634                             ساعت مارک  NaN   NaN
#
#                                                       cat                cat1  \
# 34                                     electronic-devices  electronic-devices
# 99                                               personal            personal
# 164                                              personal            personal
# 619                                              personal            personal
# 710                                    electronic-devices  electronic-devices
# 1391                                   electronic-devices  electronic-devices
# 1432                                   electronic-devices  electronic-devices
# 2213                                   electronic-devices  electronic-devices
# 3610                                   electronic-devices  electronic-devices
# 3858                                             personal            personal
# 4557                                   electronic-devices  electronic-devices
# 5081                                   electronic-devices  electronic-devices
# 5152                                   electronic-devices  electronic-devices
# 5493                                   electronic-devices  electronic-devices
# 6210                                   electronic-devices  electronic-devices
# 6239                                             personal            personal
# 6443                                   electronic-devices  electronic-devices
# 6840                                   electronic-devices  electronic-devices
# 7203                                   electronic-devices  electronic-devices
# 8229                                   electronic-devices  electronic-devices
# 9825                                   electronic-devices  electronic-devices
# 9833                                   electronic-devices  electronic-devices
# 9841                                   electronic-devices  electronic-devices
# 9960                                   electronic-devices  electronic-devices
# 10050                                  electronic-devices  electronic-devices
# 11485                                  electronic-devices  electronic-devices
# 11852                                  electronic-devices  electronic-devices
# 12512                                            personal            personal
# 12548                                  electronic-devices  electronic-devices
# 12823                                            personal            personal
# ...                                                   ...                 ...
# 947602                                vehicles:cars:light            vehicles
# 947604  for-the-home:furniture-and-home-decore:sofa-ar...        for-the-home
# 947605        electronic-devices:audio-video:tv-projector  electronic-devices
# 947606  for-the-home:building-and-garden:stove-and-hea...        for-the-home
# 947607  for-the-home:furniture-and-home-decore:tables-...        for-the-home
# 947608  for-the-home:utensils-and-appliances:cookware-...        for-the-home
# 947609                                vehicles:cars:light            vehicles
# 947610     electronic-devices:mobile-tablet:mobile-phones  electronic-devices
# 947611  businesses:equipments-and-machinery:shop-and-cash          businesses
# 947612                                vehicles:cars:heavy            vehicles
# 947613  for-the-home:furniture-and-home-decore:tables-...        for-the-home
# 947614                                vehicles:cars:heavy            vehicles
# 947615                                vehicles:cars:light            vehicles
# 947616               personal:clothing-and-shoes:clothing            personal
# 947617  for-the-home:furniture-and-home-decore:antique...        for-the-home
# 947619  for-the-home:furniture-and-home-decore:sofa-ar...        for-the-home
# 947620  for-the-home:furniture-and-home-decore:sofa-ar...        for-the-home
# 947621     electronic-devices:mobile-tablet:mobile-phones  electronic-devices
# 947622     electronic-devices:mobile-tablet:mobile-phones  electronic-devices
# 947623     businesses:equipments-and-machinery:industrial          businesses
# 947624              personal:baby-and-toys:child-car-seat            personal
# 947625                                vehicles:cars:light            vehicles
# 947626     electronic-devices:audio-video:stereo-surround  electronic-devices
# 947627  for-the-home:utensils-and-appliances:cookware-...        for-the-home
# 947628  for-the-home:furniture-and-home-decore:sofa-ar...        for-the-home
# 947630  for-the-home:building-and-garden:stove-and-hea...        for-the-home
# 947631    electronic-devices:audio-video:camera-camcoders  electronic-devices
# 947632                                vehicles:cars:light            vehicles
# 947633  electronic-devices:mobile-tablet:mobile-tablet...  electronic-devices
# 947634               personal:jewelry-and-watches:watches            personal
#
#                              cat2                       cat3
# 34                            NaN                        NaN
# 99                            NaN                        NaN
# 164                           NaN                        NaN
# 619                           NaN                        NaN
# 710                           NaN                        NaN
# 1391                          NaN                        NaN
# 1432                          NaN                        NaN
# 2213                          NaN                        NaN
# 3610                          NaN                        NaN
# 3858                          NaN                        NaN
# 4557                          NaN                        NaN
# 5081                          NaN                        NaN
# 5152                          NaN                        NaN
# 5493                          NaN                        NaN
# 6210                          NaN                        NaN
# 6239                          NaN                        NaN
# 6443                          NaN                        NaN
# 6840                          NaN                        NaN
# 7203                          NaN                        NaN
# 8229                          NaN                        NaN
# 9825                          NaN                        NaN
# 9833                          NaN                        NaN
# 9841                          NaN                        NaN
# 9960                          NaN                        NaN
# 10050                         NaN                        NaN
# 11485                         NaN                        NaN
# 11852                         NaN                        NaN
# 12512                         NaN                        NaN
# 12548                         NaN                        NaN
# 12823                         NaN                        NaN
# ...                           ...                        ...
# 947602                       cars                      light
# 947604  furniture-and-home-decore              sofa-armchair
# 947605                audio-video               tv-projector
# 947606        building-and-garden          stove-and-heating
# 947607  furniture-and-home-decore          tables-and-chairs
# 947608    utensils-and-appliances         cookware-tableware
# 947609                       cars                      light
# 947610              mobile-tablet              mobile-phones
# 947611   equipments-and-machinery              shop-and-cash
# 947612                       cars                      heavy
# 947613  furniture-and-home-decore          tables-and-chairs
# 947614                       cars                      heavy
# 947615                       cars                      light
# 947616         clothing-and-shoes                   clothing
# 947617  furniture-and-home-decore           antiques-and-art
# 947619  furniture-and-home-decore              sofa-armchair
# 947620  furniture-and-home-decore              sofa-armchair
# 947621              mobile-tablet              mobile-phones
# 947622              mobile-tablet              mobile-phones
# 947623   equipments-and-machinery                 industrial
# 947624              baby-and-toys             child-car-seat
# 947625                       cars                      light
# 947626                audio-video            stereo-surround
# 947627    utensils-and-appliances         cookware-tableware
# 947628  furniture-and-home-decore              sofa-armchair
# 947630        building-and-garden          stove-and-heating
# 947631                audio-video           camera-camcoders
# 947632                       cars                      light
# 947633              mobile-tablet  mobile-tablet-accessories
# 947634        jewelry-and-watches                    watches
#
# [947635 rows x 18 columns]
