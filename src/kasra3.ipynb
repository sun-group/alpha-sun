# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("resources/divar_posts_dataset.csv")

# %%
df["cat"] = (df["cat1"]+":"+df["cat2"]+":"+df["cat3"])

# %%
df
# Out:
#         Unnamed: 0  archive_by_user                   brand  \
# 0                0            False                     NaN
# 1                1            False                     NaN
# 2                2            False                     NaN
# 3                3            False                     NaN
# 4                4            False                     NaN
# 5                5            False                     NaN
# 6                6            False                     NaN
# 7                7            False                     NaN
# 8                8            False                    سایر
# 9                9            False                     NaN
# 10              10            False                     NaN
# 11              11            False            Nokia::نوکیا
# 12              12            False                     NaN
# 13              13            False                     NaN
# 14              14            False                     NaN
# ...
