# %%
import pandas as pd
datas = pd.read_csv("resources/dataset.csv")

# %%
for ind in range(600,700):
    row = datas.iloc[ind]
    print(str(ind + 1) + " " + row.desc + " " + row.title)
# Out:
# 601 گوشی موبایل Apple رزگلد iPhone 6s با جعبه و لوازم کامل سالم و تمیز مدل LLA اپل 6s رزگلد 16g LLA
# 602 سلام گوشی رنگ گلد 4g اندروید6 کنارش دوتا ضرب خوردگی داره با گارد دیده نمیش کارکرد1ماه باگارانتی گوشی کاملا سالم فقط فروش قیمت مقطوعه الکی زنگ نزنین و قیمت ندین باهیچی معاوضه ندارم مهلت تستم میدم فقط تلگرام فروش پولتون فقط نقد باش هواوی p8 lite
# 603 گوشی جز یه ترک ریز که روی قاب پشتش هست هیچ مشکلی نداره
# باتریش سه روز شارژ نگه میداره
# کارتن و شارژر و هندزفری داره
# ویندوزشم نسخه ی ۱۰ هستش آخرین ویرایش
# همه ی نرم افزار هارو هم داره تلگرام اینستاگرام و شیرایت و ..... لومیا ۵۴۰ سالم
# 604 گوشی A7سامسونگ 2015بدونه خط خش خیلی کم استفاده شده در حد نو حافظه داخلی 32گیگ دوربین 16 فلش عالی داره دوربین جلوشم حرف نداره خودم یک میلیونو صد خریدمش فقط خریدار واقعی تماس بگیره گوشی A7سامسونگ در حد نو
# 605 سالم
# بی خط و خش
# با قاب ورم SD
# با لوازم کامل
# 2 ماه کارکرده
# خمیده باریک زیبا
# فست شارژ
# 16 و 2
# دوربین عقب 13 4k
# جلو 5 فول اچ دی
# هشت هسته ای 3/5 اسنپدراگون
# صفحه ی OLED
# ...

# %%
final = pd.read_csv("resources/dataset.csv")

# %%
f = open("result2.txt","w")
for i in range(0,1000):
    brand = final.iloc[i].title
    f.write("%s\n" % brand)
